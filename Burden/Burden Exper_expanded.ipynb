# %%
import pandas as pd
import random
import numpy as np
import sklearn as sk
from scipy import stats
import statistics
import cvxpy as cvx
import xgboost
from sklearn.metrics import roc_curve, auc, confusion_matrix, roc_auc_score
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
xgboost.__version__
from scipy.linalg import svd
from scipy.spatial import ConvexHull
from sklearn.decomposition import PCA, NMF
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
import seaborn as sns
import math

import warnings
warnings.filterwarnings('ignore')

# %%
file_name = './compas-scores-two-years.csv'
full_data = pd.read_csv(file_name)
full_data.race.value_counts()

print(full_data.shape)

# remove groups with few instances 
full_data = full_data.query("race != 'Asian'").query("race != 'Native American'")

# group by felony or misdemenor charge
full_data.groupby(['c_charge_degree','is_recid'])['id'].count().reset_index()

# turn charge degree to numbers 
full_data['c_charge_degree'] = pd.Categorical(full_data['c_charge_degree'])
# change numbers into dummies (1 for present 0 for absent)
dummies = pd.get_dummies(full_data['c_charge_degree'], prefix='charge')
full_data = pd.concat([full_data, dummies], axis=1)

# remove bad data
full_data = full_data.query("days_b_screening_arrest <= 30") \
        .query("days_b_screening_arrest >= -30")\
        .query("is_recid != -1")\
        .query("c_charge_degree != 'O'") \
        .query("score_text != 'N/A'" )\
        .query("race != 'Asian'")\
        .query("race != 'Native American'")\
        .query("race != 'Other'")\
        .query("race != 'Hispanic'")

print(full_data.shape)

# randomize race for later use
full_data['race_random'] = np.random.permutation(full_data['race'])

# check how many random to the same thing
np.sum(full_data['race']==full_data['race_random'])

# check counts of recidivism by race
full_data.groupby(['race','is_recid'])['id'].count().reset_index()

# keep relevant columns 
columns_kept = ['sex', 'age', 'age_cat', 'race', 'juv_fel_count', 'priors_count', 'c_charge_degree', \
                'is_recid', 'decile_score', 'two_year_recid', 'c_jail_in', 'c_jail_out', 'race_random', \
                'charge_F', 'charge_M', 'score_text', 'id']
full_data = full_data.loc[:, columns_kept]

full_data = full_data.set_index('id')

full_data.head()
# Out:
# (7214, 53)
# (5278, 55)
#        sex  age       age_cat              race  juv_fel_count  priors_count  \
# id
# 3     Male   34       25 - 45  African-American              0             0
# 4     Male   24  Less than 25  African-American              0             4
# 8     Male   41       25 - 45         Caucasian              0            14
# 10  Female   39       25 - 45         Caucasian              0             0
# 14    Male   27       25 - 45         Caucasian              0             0
#
#    c_charge_degree  is_recid  decile_score  two_year_recid  \
# id
# 3                F         1             3               1
# 4                F         1             4               1
# 8                F         1             6               1
# 10               M         0             1               0
# 14               F         0             4               0
#
#               c_jail_in           c_jail_out       race_random  charge_F  \
# id
# 3   2013-01-26 03:45:27  2013-02-05 05:36:53         Caucasian         1
# 4   2013-04-13 04:58:34  2013-04-14 07:02:04  African-American         1
# 8   2014-02-18 05:08:24  2014-02-24 12:18:30         Caucasian         1
# 10  2014-03-15 05:35:34  2014-03-18 04:28:46         Caucasian         0
# 14  2013-11-25 06:31:06  2013-11-26 08:26:57  African-American         1
#
#     charge_M score_text
# id
# 3          0        Low
# 4          0        Low
# 8          0     Medium
# 10         1        Low
# 14         0        Low

# %%
learning_data = full_data.copy(deep=True)
features_to_transform = ['age_cat', 'sex', 'race', 'c_charge_degree']

for feature in features_to_transform:
    dummies = pd.get_dummies(learning_data[feature], prefix=feature)
    learning_data = pd.concat([learning_data, dummies], axis = 1)
learning_data.head()

learning_data.columns = learning_data.columns.str.replace('-', '_')

learning_data['score_factor'] = np.where(learning_data['score_text'] == 'Low', 'Low', 'MediumHigh')
dummies = pd.get_dummies(learning_data['score_factor'])
learning_data = pd.concat([learning_data, dummies] , axis = 1)
learning_data.head()
# Out:
#        sex  age       age_cat              race  juv_fel_count  priors_count  \
# id
# 3     Male   34       25 - 45  African-American              0             0
# 4     Male   24  Less than 25  African-American              0             4
# 8     Male   41       25 - 45         Caucasian              0            14
# 10  Female   39       25 - 45         Caucasian              0             0
# 14    Male   27       25 - 45         Caucasian              0             0
#
#    c_charge_degree  is_recid  decile_score  two_year_recid  ...  \
# id                                                          ...
# 3                F         1             3               1  ...
# 4                F         1             4               1  ...
# 8                F         1             6               1  ...
# 10               M         0             1               0  ...
# 14               F         0             4               0  ...
#
#    age_cat_Less than 25 sex_Female sex_Male  race_African_American  \
# id
# 3                     0          0        1                      1
# 4                     1          0        1                      1
# 8                     0          0        1                      0
# 10                    0          1        0                      0
# 14                    0          0        1                      0
#
#     race_Caucasian c_charge_degree_F  c_charge_degree_M  score_factor  Low  \
# id
# 3                0                 1                  0           Low    1
# 4                0                 1                  0           Low    1
# 8                1                 1                  0    MediumHigh    0
# 10               1                 0                  1           Low    1
# 14               1                 1                  0           Low    1
#
#     MediumHigh
# id
# 3            0
# 4            0
# 8            1
# 10           0
# 14           0
#
# [5 rows x 28 columns]

# %%
X_Labels = ['sex_Male', 'sex_Female', 'age', 'race_African_American', 'race_Caucasian', 'priors_count',\
            'juv_fel_count', 'c_charge_degree_F', 'c_charge_degree_M']
Y_Labels = ['Low']


X =  learning_data.loc[:, X_Labels]
Y =  learning_data.loc[:, Y_Labels]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size =  0.2, random_state =  4)

# find and later remove linearly correlated pairs (not for xgboost but for LOCO later)
corr_thresh = .7
for column_a in X.columns:
    for column_b in X.columns:
        if column_a is not column_b:
            if X[column_a].corr(X[column_b]) > corr_thresh:
                print(column_a + " " + column_b)
    

xgb_full = xgboost.DMatrix(X, label=Y)
xgb_train =  xgboost.DMatrix(X_train, label = Y_train)
xgb_test = xgboost.DMatrix(X_test, label = Y_test)
# use validation set to choose # of trees
params = {
    "eta": 0.002,
    "max_depth": 4,
    "objective": 'binary:logistic',
    "eval_metric":"auc",
    "tree_method": 'gpu_hist',
    "subsample": 0.5
}
#model_train = xgboost.train(params, xgb_train, 10000, evals = [(xgb_test, "test")], verbose_eval=1000)
model = xgboost.train(params, xgb_train, 10000, evals = [(xgb_test, "test")], verbose_eval= 1000)
xgboost.cv(params,xgb_full, nfold = 3, metrics="auc" , num_boost_round=10)
learning_data['pred'] = model.predict(xgb_full)
# Out:
# [0]	test-auc:0.80809
# [1000]	test-auc:0.83846
# [2000]	test-auc:0.83932
# [3000]	test-auc:0.83820
# [4000]	test-auc:0.83604
# [5000]	test-auc:0.83403
# [6000]	test-auc:0.83267
# [7000]	test-auc:0.83148
# [8000]	test-auc:0.83019
# [9000]	test-auc:0.82912
# [9999]	test-auc:0.82775

# %%
plt.hist(learning_data['pred'], bins = 20)
plt.show()

# %%
# %matplotlib inline
fpr, tpr , thresholds = roc_curve(learning_data['Low'], learning_data['pred'])
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

optimal_threshold = thresholds[np.argmax(tpr - fpr)]
print("Optimal Threshold obtained using difference of TPR and FPR " + str(optimal_threshold))
learning_data['y_pred'] = np.where(learning_data['pred'] > optimal_threshold, 1, 0)
# Out:
# Optimal Threshold obtained using difference of TPR and FPR 0.5208177

# %% [markdown]
# ## Find Burden

# %%
class CounterFactFactory:
    # do we need to mutate catagorical and continous data seperately? 
    # we probably need to ask for some bounds on each feature

    # bounds is a dict with form {<feature_name>: (<"catagorical"/"continous">, <number catagories/continous scale>)}
    # continous scale is max value for generating the initial population continous features
    # -(continous scale) is min value for generating the initial population
    def __init__(self, indiv, model_pred_func, bounds, fit_func, 
               selection_rate=.5, prob_mut=.2, prob_cross=.5, init_pop_size=1000,
               round_func=np.around, generations=200, stall_eps=.001, min_iter=5,
               random_state=None,
                 **kwargs):
        self.model_pred_func = model_pred_func  # f(x)
        self.indiv = indiv                      # x
        self.c_fact_list = pd.DataFrame()       # subset of I
        self.feature_bounds = bounds            # may be used for mutation
        self.fitness = fit_func                 # d(x, c)
        self.pop_size = init_pop_size
        self.round_func = round_func
        self.p_s = selection_rate
        self.p_m = prob_mut
        self.p_c = prob_cross
        self.indiv_class = self.round_func(self.model_pred_func(xgboost.DMatrix(self.indiv)))
        self.indiv_class = self.indiv_class[0]
        self.gen = generations
        self.stall_eps = stall_eps
        self.stall_time = min_iter
        
        self.catL = [] 
        self.conL = []
        self.feature_names =  []
        
        np.random.seed(random_state)
        
        for feature_name in self.feature_bounds:
            bounds = self.feature_bounds[feature_name]
            self.feature_names.append(feature_name)
            if bounds[0].startswith("cat"):
                self.catL.append(feature_name)
            elif bounds[0].startswith("cont"):
                self.conL.append(feature_name)
            else:
                print("error in bounds dictionary")
                print("expected catagorical or continous and got neither")
                raise ValueError()



    # step 7
    def genRandomCFactuals(self):
        
        temp = None
        if not self.c_fact_list.empty:
            temp = self.c_fact_list.columns
            
        # keep generating counter factuals until our population is up to size
        while self.c_fact_list.shape[0] < self.pop_size:
            # generate new individuals
            new_indivs = pd.DataFrame()
            for feature_name in self.feature_names:
                bounds = self.feature_bounds[feature_name]
                if bounds[0].startswith("cat"):
                    # catagorical random
                    new_indivs[feature_name] = np.random.randint(0, bounds[1], size=self.pop_size-self.c_fact_list.shape[0])
                elif bounds[0].startswith("cont"):
                    # continous random
                    new_indivs[feature_name] = np.random.rand(self.pop_size-self.c_fact_list.shape[0], 1) * (bounds[1])
                else:
                    print("error in bounds dictionary")
                    print("expected catagorical or continous and got neither")
            # calculate new predictions and filter
            new_indivs['prediction'] = new_indivs.apply(lambda row : 
                                                      self.round_func(self.model_pred_func(xgboost.DMatrix(pd.DataFrame(row).T)))[0],
                                                      axis = 1)
            new_indivs = new_indivs[new_indivs.prediction != self.indiv_class]

            # add the survivors to the dataframe
            if temp is None:
                temp = new_indivs.columns
                
            self.c_fact_list = pd.concat([self.c_fact_list, new_indivs], axis=0)
            self.c_fact_list = self.c_fact_list[temp]
            
    # step 8
    def selection(self):
        if self.c_fact_list is pd.DataFrame.empty:
            print("attempted to select on an empty population")
            print("try calling genRandomCFactuals first?")
            print("if this appears from a call of getCFactuals then its a bug. please report it")
            return

        # sort by fitness and then keep the top half
        self.c_fact_list['fitness'] = self.c_fact_list.apply(lambda row : 
                                                             self.fitness(self.indiv, row, self.catL, self.conL),
                                                             axis=1)
        self.c_fact_list = (self.c_fact_list.loc[self.c_fact_list.fitness.sort_values(ascending=False).index
                                                 ])[:int(self.c_fact_list.shape[0]*self.p_s)]

    # step 9
    def mutation(self):
        # get individuals to mutate
        to_mut_indivs = self.c_fact_list.sample(frac=self.p_m, axis=0)

        # mutate the individuals
        for feature_name in self.feature_names:
            bounds = self.feature_bounds[feature_name]
            if bounds[0].startswith("cat"):
                # catagorical random
                self.c_fact_list.loc[to_mut_indivs.index, feature_name] = np.random.randint(0, bounds[1], size=to_mut_indivs.shape[0])
            elif bounds[0].startswith("cont"):
                # continous random
                self.c_fact_list.loc[to_mut_indivs.index, feature_name] = np.random.rand(to_mut_indivs.shape[0], 1) * (bounds[1])
            else:
                print("error in bounds dictionary")
                print("expected catagorical or continous and got neither")

          

        # set the counter factuals to their mutated version
        self.c_fact_list.loc[to_mut_indivs.index] = to_mut_indivs

        # recalculate the predictions
        self.c_fact_list.drop('prediction', inplace=True, axis=1)
        self.c_fact_list.drop('fitness', inplace=True, axis=1)
        self.c_fact_list['prediction'] = self.c_fact_list.apply(lambda row : 
                                                self.round_func(self.model_pred_func(xgboost.DMatrix(pd.DataFrame(row).T)))[0],
                                                axis = 1)
        
        # recalculate the fitnesses for use later
        self.c_fact_list['fitness'] = self.c_fact_list.apply(lambda row : 
                                                             self.fitness(self.indiv, row, self.catL, self.conL),
                                                             axis = 1)

    # step 10
    def crossover(self):
        # make sure to recalculate the fitnesses, and predictions
        # make sure to filter out
        # idea: 
        #1. sort by fitness, and keep top p_c portion. 
        #2. cross over between c_0 & c_1, c_2 & c_3, and so on
        #3. to cross over, swap each feature value with 50% probability
        self.c_fact_list['fitness'] = self.c_fact_list.apply(lambda row : 
                                                             self.fitness(self.indiv, row, self.catL, self.conL),
                                                             axis = 1)
        self.c_fact_list = (self.c_fact_list.loc[self.c_fact_list.fitness.sort_values(ascending=False).index])
        self.c_fact_list.drop('prediction', inplace=True, axis=1)
        self.c_fact_list.drop('fitness', inplace=True, axis=1)
        
        count = self.c_fact_list.shape[0] * self.p_c
        i = 0
        while i < count:
            for feature_name in self.feature_bounds:
                if(np.random.random_sample() > 0.5):
                    old_val = self.c_fact_list.loc[i, feature_name]
                    self.c_fact_list.loc[i, feature_name] = self.c_fact_list.loc[i+1, feature_name]
                    self.c_fact_list.loc[i, feature_name] = old_val
            i = i + 2
        pass
    
        self.c_fact_list['prediction'] = self.c_fact_list.apply(lambda row : 
                                        self.round_func(self.model_pred_func(xgboost.DMatrix(pd.DataFrame(row).T)))[0],
                                        axis = 1)

        # recalculate the fitnesses for use later
        self.c_fact_list['fitness'] = self.c_fact_list.apply(lambda row : 
                                                             self.fitness(self.indiv, row, self.catL, self.conL),
                                                             axis = 1)


    # step 11
    def filterCFacts(self):
        # filter the population of counter factuals (self.c_fact_list) to remove all
        # individuals that have the same prediction class (self.indiv_class) as the original 
        # individual (self.indiv)
        self.c_fact_list = self.c_fact_list[self.c_fact_list.prediction != self.indiv_class]
        pass

    # step 12
    def getCFactuals(self):
        max_list = []
        
        for generation in range(self.gen):
            self.genRandomCFactuals()
            self.c_fact_list.reset_index(drop=True, inplace=True)
            
            self.selection()
            self.c_fact_list.reset_index(drop=True, inplace=True)
            
            self.mutation()
            self.c_fact_list.reset_index(drop=True, inplace=True)

            self.crossover()
            self.c_fact_list.reset_index(drop=True, inplace=True)

            self.filterCFacts()
            self.c_fact_list.reset_index(drop=True, inplace=True)
            
            max_list.append(self.c_fact_list.fitness.max())
                        
            if len(max_list) > self.stall_time and (np.array(max_list)[-self.stall_time:] == max_list[-1]).sum() >= self.stall_time :
                print("stalled out on generation", generation,
                      "with max fitness", self.c_fact_list.fitness.max())
                return self.c_fact_list[self.c_fact_list.fitness == self.c_fact_list.fitness.max()]
            
            if(generation == self.gen-1):
                print("Generation", generation, "with max fitness", self.c_fact_list.fitness.max())
            
        return self.c_fact_list[self.c_fact_list.fitness == self.c_fact_list.fitness.max()]

# %%
def d(indiv, other, cat, con):
    
    agg = pd.DataFrame(indiv)
    agg.loc[1] = other
    agg.reset_index(drop=True, inplace=True)
    
    ncat = len(cat)
    ncon = len(con)
    
    xcat = agg.loc[:, cat]
    xcon = agg.loc[:, con]
        
    # MAD normalized L1 Norm
    normedl1norm = 0
    for feature in con:
        mad = madArray[feature]
        normedl1norm += abs(xcon.iloc[0,:].loc[feature] - xcon.iloc[1,:].loc[feature]) / mad

        
    # simpMat
    # both pos
    xcat = xcat.astype('int32')
    PosMat = xcat.loc[0] & xcat.loc[1] 
    NegMat = (1 - xcat.loc[0]) & (1 - xcat.loc[1])
    total = xcat.shape[1]
    dist = (PosMat.sum() + NegMat.sum())/total
    
    n = ncat + ncon
    return ncon*normedl1norm/n + ncat*dist/n

# %%
b = {
    'sex_Male':   ("catagorical", 2),
    'sex_Female': ("catagorical", 2),
    'age':        ("continous", 100),
    'race_African_American': ("catagorical", 2),
    'race_Caucasian': ("catagorical", 2),
    'priors_count':   ("continous", 100),
    'juv_fel_count':  ("continous", 100),
    'c_charge_degree_F': ("catagorical", 2),
    'c_charge_degree_M': ("catagorical", 2)
}

cdf = pd.DataFrame(columns=['fitness']+X_Labels)
burden_data = learning_data.loc[:, X_Labels]

madArray = {}
for feature in b:
    bounds = b[feature]
    if bounds[0].startswith("cont"):
        madArray[feature] = burden_data.loc[:, feature].mad()

def inv_dist(ind, otr, cat, con):
    return 1 / d(ind, otr, cat, con)

#for i in range(int(learning_data.shape[0])):
#    
#    burden_indiv = pd.DataFrame(burden_data.iloc[i]).T
    
#    c_fact = CounterFactFactory(indiv=burden_indiv, model_pred_func=model.predict, bounds=b, 
#                                fit_func=inv_dist, init_pop_size=100, generations=50, random_state=4,
#                                min_iter=25)

#    print("working on indiv", str(i))
#    final_c_fact = c_fact.getCFactuals()
#    cdf = cdf.append(final_c_fact)

# attempt at vectorization
factories = burden_data.apply(lambda row: CounterFactFactory(indiv=pd.DataFrame(row).T, model_pred_func=model.predict, bounds=b, 
                              fit_func=inv_dist, init_pop_size=100, generations=50, random_state=4,
                              min_iter=25), axis = 1)

cdf = factories.apply(lambda fact: fact.getCFactuals())

cdf.index = burden_data.index
cdf.head()
# Out:
# id
# 3     <__main__.CounterFactFactory object at 0x00000...
# 4     <__main__.CounterFactFactory object at 0x00000...
# 8     <__main__.CounterFactFactory object at 0x00000...
# 10    <__main__.CounterFactFactory object at 0x00000...
# 14    <__main__.CounterFactFactory object at 0x00000...
# dtype: object
# Generation 49 with max fitness 0.43243132115413113
# Generation 49 with max fitness 0.5444738838539323
# stalled out on generation 39 with max fitness 0.5292263280431125
# stalled out on generation 31 with max fitness 0.42645623943649213
# stalled out on generation 33 with max fitness 0.26401587770160345
# stalled out on generation 28 with max fitness 0.4665890955702843
# stalled out on generation 32 with max fitness 0.3242729071109554
# stalled out on generation 26 with max fitness 0.18088928888500008
# stalled out on generation 28 with max fitness 0.523136413058845
# stalled out on generation 34 with max fitness 0.6306562751811831
# stalled out on generation 28 with max fitness 0.6186703994954312
# Generation 49 with max fitness 0.7915388367876846
# Generation 49 with max fitness 0.9645209377456466
# Generation 49 with max fitness 0.7921451084269158
# stalled out on generation 27 with max fitness 0.5492774807783208
# Generation 49 with max fitness 0.594322592655219
# stalled out on generation 45 with max fitness 0.7557347316241075
# stalled out on generation 27 with max fitness 0.28285543071614544
# Generation 49 with max fitness 0.6269034921855609
# stalled out on generation 38 with max fitness 0.7176599556495461
# stalled out on generation 27 with max fitness 0.21762631334147123
# stalled out on generation 25 with max fitness 0.565895901156776
# Generation 49 with max fitness 0.9970336385067804
# Generation 49 with max fitness 0.3963986657517055
# stalled out on generation 27 with max fitness 1.003380711487423
# stalled out on generation 39 with max fitness 0.4433448949619195
# stalled out on generation 26 with max fitness 0.5786523477128785
# Generation 49 with max fitness 0.27624586919964367
# stalled out on generation 25 with max fitness 0.536962337829428
# Generation 49 with max fitness 0.3532850646524054
# stalled out on generation 44 with max fitness 1.0780344491152818
# Generation 49 with max fitness 0.8415580304204033
# stalled out on generation 25 with max fitness 0.2643989899866212
# Generation 49 with max fitness 0.5288752025749992
# Generation 49 with max fitness 0.7241650783583581
# Generation 49 with max fitness 0.39992686298494023
# stalled out on generation 27 with max fitness 0.2966597800357572
# stalled out on generation 26 with max fitness 0.23587662774601953
# stalled out on generation 29 with max fitness 0.40274077077120957
# stalled out on generation 25 with max fitness 0.6908565919586506
# stalled out on generation 41 with max fitness 0.6074165725873937
# stalled out on generation 49 with max fitness 0.3451069775453454
# stalled out on generation 36 with max fitness 0.6761079777232758
# stalled out on generation 46 with max fitness 0.6552147798469292
# stalled out on generation 26 with max fitness 0.23461074993212688
# stalled out on generation 45 with max fitness 0.9643995803777662
# stalled out on generation 39 with max fitness 0.7852537698072847
# stalled out on generation 29 with max fitness 0.5388737770048485
# stalled out on generation 35 with max fitness 0.46663686080394745
# stalled out on generation 25 with max fitness 0.28895341634191524
# stalled out on generation 28 with max fitness 0.5893059016795625
# Generation 49 with max fitness 0.34296312999970524
# Generation 49 with max fitness 0.3258951081540144
# stalled out on generation 48 with max fitness 0.745285220134225
# stalled out on generation 30 with max fitness 0.4816265381244745
# stalled out on generation 30 with max fitness 0.44929392888194053
# stalled out on generation 43 with max fitness 0.3059948422949119
# stalled out on generation 25 with max fitness 0.40448433582296417
# Generation 49 with max fitness 0.5192488294699376
# stalled out on generation 33 with max fitness 0.5128389007406245
# stalled out on generation 39 with max fitness 0.959415977882642
# stalled out on generation 27 with max fitness 0.43591760439292465
# Generation 49 with max fitness 0.5957234070159216
# Generation 49 with max fitness 0.5020839160439078
# stalled out on generation 39 with max fitness 0.4857179332486763
# stalled out on generation 25 with max fitness 0.9406174092069461
# stalled out on generation 25 with max fitness 0.254047604906829
# Generation 49 with max fitness 0.234069747476108
# stalled out on generation 37 with max fitness 0.39226271812723423
# Generation 49 with max fitness 0.25999778747811203
# Generation 49 with max fitness 0.57453815935993
# stalled out on generation 47 with max fitness 0.7370765754791964
# stalled out on generation 32 with max fitness 0.2250420068155542
# stalled out on generation 25 with max fitness 0.4313863962672879
# stalled out on generation 42 with max fitness 0.42377235023118703
# stalled out on generation 40 with max fitness 0.215465441701686
# Generation 49 with max fitness 0.8437367007042778
# stalled out on generation 47 with max fitness 0.32158583692309783
# stalled out on generation 49 with max fitness 0.44790442368099775
# Generation 49 with max fitness 0.49449344390646577
# stalled out on generation 46 with max fitness 0.4527308417906136
# stalled out on generation 43 with max fitness 0.38173854705143623
# stalled out on generation 46 with max fitness 0.7422722043332521
# stalled out on generation 26 with max fitness 0.30451894460634693
# stalled out on generation 39 with max fitness 0.31584440966584976
# stalled out on generation 36 with max fitness 0.5170488975031976
# stalled out on generation 25 with max fitness 0.5215663277396988
# Generation 49 with max fitness 0.685147199338255
# stalled out on generation 38 with max fitness 0.2940450446188763
# stalled out on generation 25 with max fitness 0.40662051038069646
# stalled out on generation 43 with max fitness 0.7578152635482968
# stalled out on generation 49 with max fitness 1.1002302369744608
# Generation 49 with max fitness 0.4520792139539629
# Generation 49 with max fitness 0.31731348651000685
# stalled out on generation 36 with max fitness 0.21868984028507937
# stalled out on generation 43 with max fitness 0.5796499463685514
# stalled out on generation 43 with max fitness 0.35740785313750545
# stalled out on generation 46 with max fitness 0.41576389268139247
# stalled out on generation 27 with max fitness 0.3683284512371502
# stalled out on generation 44 with max fitness 0.2519590805400274
# Generation 49 with max fitness 0.570570543648635
# stalled out on generation 25 with max fitness 0.5770382768383111
# stalled out on generation 46 with max fitness 0.5040352835209542
# stalled out on generation 40 with max fitness 0.6514256660454631
# stalled out on generation 42 with max fitness 0.5296776001983713
# Generation 49 with max fitness 0.568911992318096
# stalled out on generation 26 with max fitness 0.16862012694856335
# stalled out on generation 25 with max fitness 0.7165536928514089
# stalled out on generation 47 with max fitness 0.5518990547954553
# Generation 49 with max fitness 0.6229275055865541
# Generation 49 with max fitness 0.37576220737385585
# stalled out on generation 28 with max fitness 0.2907467178109163
# stalled out on generation 39 with max fitness 1.305730112389063
# stalled out on generation 25 with max fitness 0.5731818731986625
# stalled out on generation 33 with max fitness 0.4897508098212424
# Generation 49 with max fitness 1.0012062273229003
# stalled out on generation 40 with max fitness 0.24245143975244798
# stalled out on generation 25 with max fitness 0.47939252695268386
# stalled out on generation 35 with max fitness 0.3675384678481081
# stalled out on generation 28 with max fitness 0.457114369658642
# Generation 49 with max fitness 0.3123562964506873
# Generation 49 with max fitness 0.9683992111217343
# stalled out on generation 49 with max fitness 0.6789431968819816
# stalled out on generation 33 with max fitness 0.39735853784461
# stalled out on generation 26 with max fitness 0.4996037438455099
# Generation 49 with max fitness 0.5511091414070197
# stalled out on generation 41 with max fitness 0.5600491972198046
# stalled out on generation 25 with max fitness 0.3630321181062374
# Generation 49 with max fitness 0.42325585204824917
# stalled out on generation 25 with max fitness 0.43456775905464656
# Generation 49 with max fitness 0.44559185574049415
# stalled out on generation 30 with max fitness 0.35662702425429377
# stalled out on generation 36 with max fitness 0.3365981357841951
# Generation 49 with max fitness 0.6217424481458683
# Generation 49 with max fitness 0.5901647286410674
# stalled out on generation 39 with max fitness 0.2604134846635957
# stalled out on generation 25 with max fitness 0.2688570937296918
# stalled out on generation 28 with max fitness 0.2617773703966754
# stalled out on generation 40 with max fitness 0.23291410823357886
# Generation 49 with max fitness 0.321652201383028
# stalled out on generation 36 with max fitness 0.2456273516762196
# stalled out on generation 25 with max fitness 0.4204166230456568
# stalled out on generation 25 with max fitness 0.34810009312165785
# stalled out on generation 36 with max fitness 0.5668383302867334
# Generation 49 with max fitness 0.5558862856452857
# stalled out on generation 43 with max fitness 0.2876853827316961
# Generation 49 with max fitness 0.6692734425380484
# Generation 49 with max fitness 0.3821063977608222
# stalled out on generation 29 with max fitness 0.18385679877372146
# stalled out on generation 26 with max fitness 0.37710238983912125
# stalled out on generation 34 with max fitness 0.9045161146776586
# stalled out on generation 29 with max fitness 0.2355719683559074
# stalled out on generation 43 with max fitness 0.20933404385644575
# Generation 49 with max fitness 0.2567453019087725
# stalled out on generation 41 with max fitness 0.283754949864701
# stalled out on generation 35 with max fitness 0.21898969068600094
# Generation 49 with max fitness 0.3100131548165901
# stalled out on generation 35 with max fitness 1.4500644706234924
# stalled out on generation 36 with max fitness 0.8525830540578531
# stalled out on generation 27 with max fitness 0.3498418333770808
# stalled out on generation 25 with max fitness 0.8063091648828898
# stalled out on generation 33 with max fitness 1.049455929227888
# stalled out on generation 40 with max fitness 0.5848084115358281
# stalled out on generation 33 with max fitness 0.2557957567012008
# Generation 49 with max fitness 0.7463327287399726
# stalled out on generation 40 with max fitness 0.3520053355161672
# stalled out on generation 37 with max fitness 0.2346492923267433
# stalled out on generation 33 with max fitness 0.5913825957384946
# Generation 49 with max fitness 0.23127575671160625
# Generation 49 with max fitness 0.24139233130778215
# stalled out on generation 36 with max fitness 0.26868122677045037
# stalled out on generation 32 with max fitness 0.5454790204212766
# stalled out on generation 33 with max fitness 0.4835554755524472
# Generation 49 with max fitness 0.7465779090581626
# stalled out on generation 32 with max fitness 0.3307964779080748
# stalled out on generation 25 with max fitness 0.40410871944980237
# stalled out on generation 37 with max fitness 0.6024763098315016
# stalled out on generation 46 with max fitness 0.2618626193570039
# stalled out on generation 38 with max fitness 0.5930198537904954
# stalled out on generation 33 with max fitness 0.779023541699242
# stalled out on generation 29 with max fitness 0.2235256710130649
# Generation 49 with max fitness 0.9138446565466299
# stalled out on generation 42 with max fitness 0.23823853841090456
# stalled out on generation 44 with max fitness 1.016880323991436
# stalled out on generation 26 with max fitness 0.72030473170843
# stalled out on generation 35 with max fitness 0.377272784596745
# Generation 49 with max fitness 0.35517780403210375
# stalled out on generation 26 with max fitness 3.3098838427689725
# stalled out on generation 36 with max fitness 0.4515341453836464
# stalled out on generation 42 with max fitness 0.5854305406836021
# stalled out on generation 28 with max fitness 0.3640056450951651
# stalled out on generation 42 with max fitness 0.56772588405937
# Generation 49 with max fitness 1.2988062454041664
# stalled out on generation 30 with max fitness 0.5038999980714752
# stalled out on generation 46 with max fitness 0.35661072444723246
# Generation 49 with max fitness 0.4141609760916475
# stalled out on generation 42 with max fitness 0.45583843461846224
# stalled out on generation 26 with max fitness 0.7950001593614424
# stalled out on generation 25 with max fitness 0.5745654319858636
# stalled out on generation 35 with max fitness 0.9937321405305835
# stalled out on generation 42 with max fitness 0.5926605268351859
# stalled out on generation 45 with max fitness 0.39265756559138604
# stalled out on generation 39 with max fitness 0.19386229280594253
# stalled out on generation 42 with max fitness 0.3121839941738588
# stalled out on generation 32 with max fitness 0.42556465925723314
# Generation 49 with max fitness 0.5776292191668173
# Generation 49 with max fitness 0.3652818680475465
# stalled out on generation 25 with max fitness 0.27292374515661083
# stalled out on generation 46 with max fitness 0.4905172383304379
# stalled out on generation 25 with max fitness 0.7870937161246647
# stalled out on generation 25 with max fitness 0.2358895866001092
# stalled out on generation 25 with max fitness 0.29773406874765623
# Generation 49 with max fitness 1.17952047668097
# stalled out on generation 38 with max fitness 0.5261025158872321
# stalled out on generation 33 with max fitness 0.45630148427326084
# stalled out on generation 25 with max fitness 0.2232800915501162
# stalled out on generation 29 with max fitness 0.2618903404928385
# stalled out on generation 47 with max fitness 0.32216649380336826
# stalled out on generation 37 with max fitness 0.47816301606740835
# stalled out on generation 49 with max fitness 0.41137617582032726
# Generation 49 with max fitness 0.3047192085583465
# Generation 49 with max fitness 0.7791698154078637
# Generation 49 with max fitness 0.645509513390208
# stalled out on generation 41 with max fitness 0.9625074820139685
# stalled out on generation 43 with max fitness 0.635438209366922
# stalled out on generation 25 with max fitness 0.24243898031708624
# stalled out on generation 32 with max fitness 0.39486208142579965
# stalled out on generation 29 with max fitness 0.18680596604597294
# stalled out on generation 40 with max fitness 0.49010725726469595
# stalled out on generation 35 with max fitness 0.6737318632746471
# stalled out on generation 27 with max fitness 0.4657962529594266
# stalled out on generation 44 with max fitness 0.34933247589322514
# stalled out on generation 35 with max fitness 0.47866828166161396
# stalled out on generation 30 with max fitness 0.18937163066827625
# stalled out on generation 25 with max fitness 0.2903197807435908
# Generation 49 with max fitness 0.7409455548397725
# stalled out on generation 26 with max fitness 1.0433465232379568
# stalled out on generation 46 with max fitness 0.31215979243189595
# Generation 49 with max fitness 0.3953145114121055
# Generation 49 with max fitness 0.7430562444647065
# Generation 49 with max fitness 1.1732060779009092
# Generation 49 with max fitness 0.3707390904953863
# Generation 49 with max fitness 0.6422833646016007
# stalled out on generation 32 with max fitness 1.330919044824466
# stalled out on generation 25 with max fitness 0.5195416820517362
# stalled out on generation 25 with max fitness 0.957666313705903
# stalled out on generation 28 with max fitness 0.26076992803731314
# stalled out on generation 47 with max fitness 0.33220069331541346
# stalled out on generation 39 with max fitness 0.19708627512741309
# stalled out on generation 41 with max fitness 0.45364638978647565
# Generation 49 with max fitness 0.44408781275657316
# Generation 49 with max fitness 0.8148065392722487
# Generation 49 with max fitness 0.9730609615246673
# Generation 49 with max fitness 0.7817571166369381
# stalled out on generation 29 with max fitness 0.8147220936591042
# Generation 49 with max fitness 0.22532618830448425
# stalled out on generation 29 with max fitness 0.3400492583329606
# stalled out on generation 28 with max fitness 0.40987663374926814
# stalled out on generation 42 with max fitness 0.49010127418976407
# Generation 49 with max fitness 0.5271757945234573
# stalled out on generation 41 with max fitness 0.49885041899245325
# stalled out on generation 48 with max fitness 0.2876614580621977
# stalled out on generation 28 with max fitness 0.371043790293076
# Generation 49 with max fitness 0.7629468091468612
# stalled out on generation 48 with max fitness 0.5563191393547219
# stalled out on generation 27 with max fitness 0.6306754957566773
# stalled out on generation 38 with max fitness 0.35772096498475475
# stalled out on generation 25 with max fitness 0.29739978828973274
# stalled out on generation 36 with max fitness 0.3318085034953967
# stalled out on generation 27 with max fitness 0.5789857195743389
# Generation 49 with max fitness 0.6038291188782556
# Generation 49 with max fitness 0.21372356337007573
# stalled out on generation 25 with max fitness 0.6562320937354238
# stalled out on generation 36 with max fitness 0.8582741286665394
# stalled out on generation 43 with max fitness 0.29464649127778436
# Generation 49 with max fitness 0.5043760311367944
# stalled out on generation 40 with max fitness 0.7827490345756275
# stalled out on generation 40 with max fitness 0.46306934061455035
# Generation 49 with max fitness 0.24326740393439228
# Generation 49 with max fitness 0.43141132129808346
# stalled out on generation 32 with max fitness 0.8575429105463338
# Generation 49 with max fitness 0.34032656117052473
# Generation 49 with max fitness 0.3315786334491082
# stalled out on generation 31 with max fitness 0.1984092750765613
# stalled out on generation 34 with max fitness 0.3173469544425767
# stalled out on generation 49 with max fitness 0.7884340307409626
# stalled out on generation 46 with max fitness 0.6290642296413155
# stalled out on generation 28 with max fitness 0.5230394930394605
# stalled out on generation 34 with max fitness 0.33288129194731747
# stalled out on generation 25 with max fitness 0.3241517213515866
# stalled out on generation 30 with max fitness 0.378464421965969
# stalled out on generation 34 with max fitness 0.5600512978938225
# stalled out on generation 44 with max fitness 0.8823029549581107
# stalled out on generation 33 with max fitness 0.7725303331430785
# stalled out on generation 42 with max fitness 0.43150162246791257
# stalled out on generation 27 with max fitness 0.3267308693340746
# Generation 49 with max fitness 0.5756033873963529
# Generation 49 with max fitness 0.42652181834881125
# stalled out on generation 31 with max fitness 0.27451461310055947
# stalled out on generation 26 with max fitness 0.21644870943955363
# stalled out on generation 39 with max fitness 0.8353766491474094
# Generation 49 with max fitness 0.6335979526630607
# stalled out on generation 35 with max fitness 0.2544966624523689
# stalled out on generation 34 with max fitness 0.23053125362206847
# stalled out on generation 47 with max fitness 0.5821199407572231
# stalled out on generation 31 with max fitness 0.44278890028849804
# stalled out on generation 25 with max fitness 0.30319829175606605
# stalled out on generation 25 with max fitness 0.7910446560662822
# stalled out on generation 43 with max fitness 0.35240640190064754
# stalled out on generation 33 with max fitness 0.4447860630955459
# Generation 49 with max fitness 0.8770613929126497
# Generation 49 with max fitness 0.25010190968314283
# stalled out on generation 36 with max fitness 0.20488592939452982
# Generation 49 with max fitness 0.3559955323100956
# stalled out on generation 26 with max fitness 1.5181175340160689
# stalled out on generation 36 with max fitness 0.29608665108139304
# stalled out on generation 42 with max fitness 0.32483414531981514
# stalled out on generation 46 with max fitness 0.31774784079979357
# stalled out on generation 44 with max fitness 0.5626616125212947
# stalled out on generation 47 with max fitness 0.40824111430324383
# stalled out on generation 34 with max fitness 0.26248568521933124
# Generation 49 with max fitness 0.6459817730459094
# stalled out on generation 43 with max fitness 0.4883193347763944
# Generation 49 with max fitness 0.367299820387461
# stalled out on generation 42 with max fitness 0.6160758320958776
# stalled out on generation 44 with max fitness 1.1567551598365824
# Generation 49 with max fitness 0.34158980076333556
# stalled out on generation 33 with max fitness 0.20679170244149433
# stalled out on generation 40 with max fitness 0.7480044567808591
# Generation 49 with max fitness 0.36771798639619996
# stalled out on generation 33 with max fitness 0.46607799558534
# stalled out on generation 26 with max fitness 0.42259637798098193
# stalled out on generation 29 with max fitness 0.34922247521669764
# stalled out on generation 46 with max fitness 1.3580305339979204
# stalled out on generation 33 with max fitness 0.3444141473889033
# stalled out on generation 25 with max fitness 0.2245428653271234
# stalled out on generation 42 with max fitness 0.9914431624169309
# stalled out on generation 29 with max fitness 0.4616220011874234
# Generation 49 with max fitness 0.2702083213607406
# stalled out on generation 35 with max fitness 0.5022231063822216
# stalled out on generation 37 with max fitness 0.37913173085281426
# stalled out on generation 26 with max fitness 0.311564396827653
# stalled out on generation 29 with max fitness 0.24308438251618117
# Generation 49 with max fitness 0.8503009826875731
# stalled out on generation 37 with max fitness 0.6179157457709522
# stalled out on generation 28 with max fitness 0.28375770121243754
# stalled out on generation 35 with max fitness 0.5210415706511141
# stalled out on generation 47 with max fitness 0.4573924155395464
# Generation 49 with max fitness 0.4794667238814581
# stalled out on generation 27 with max fitness 0.6583066968848171
# stalled out on generation 36 with max fitness 0.4751945302460233
# stalled out on generation 45 with max fitness 0.4187459276320841
# Generation 49 with max fitness 0.43312545356618465
# stalled out on generation 30 with max fitness 0.32243725956988617
# stalled out on generation 41 with max fitness 0.8226075563957487
# Generation 49 with max fitness 0.3232006317175544
# Generation 49 with max fitness 0.37980895463318265
# stalled out on generation 29 with max fitness 0.4268442447698936
# Generation 49 with max fitness 0.4346535351317297
# stalled out on generation 25 with max fitness 0.28225248643912854
# Generation 49 with max fitness 0.35796901159587774
# stalled out on generation 36 with max fitness 0.6315823146792365
# stalled out on generation 32 with max fitness 1.7141750278655012
# Generation 49 with max fitness 0.5996883760791747
# stalled out on generation 40 with max fitness 0.7382253802187164
# stalled out on generation 35 with max fitness 0.37546414732269995
# stalled out on generation 41 with max fitness 0.6415591559631498
# stalled out on generation 45 with max fitness 0.5837322077635143
# stalled out on generation 37 with max fitness 0.639273834363735
# stalled out on generation 42 with max fitness 0.5621268002188529
# stalled out on generation 29 with max fitness 0.3151290181314781
# Generation 49 with max fitness 0.7767027034465477
# Generation 49 with max fitness 0.5613286667068791
# stalled out on generation 42 with max fitness 0.3288884742004771
# stalled out on generation 43 with max fitness 0.6682992756034621
# stalled out on generation 25 with max fitness 0.22909815095504002
# stalled out on generation 37 with max fitness 0.7960968366278237
# stalled out on generation 25 with max fitness 0.38643892806125596
# stalled out on generation 42 with max fitness 0.3642250383792934
# Generation 49 with max fitness 0.576464354989212
# stalled out on generation 43 with max fitness 0.559277878670165
# stalled out on generation 25 with max fitness 0.4334907758728665
# stalled out on generation 44 with max fitness 0.645440718156597
# Generation 49 with max fitness 0.39510456540659167
# stalled out on generation 38 with max fitness 0.46464905002493334
# stalled out on generation 44 with max fitness 1.586672615481397
# stalled out on generation 43 with max fitness 0.6809951004916227
# Generation 49 with max fitness 0.6325985897392901
# stalled out on generation 25 with max fitness 0.9935343116761435
# stalled out on generation 27 with max fitness 0.2986481947864621
# stalled out on generation 38 with max fitness 0.408313643616301
# stalled out on generation 34 with max fitness 0.3433871808016791
# stalled out on generation 36 with max fitness 0.5386947495045021
# Generation 49 with max fitness 0.44808435762864524
# stalled out on generation 36 with max fitness 0.40144161936004524
# Generation 49 with max fitness 0.3336111464779093
# stalled out on generation 34 with max fitness 0.5123406162619053
# stalled out on generation 27 with max fitness 0.3431090706572548
# stalled out on generation 26 with max fitness 0.37719661124169396
# stalled out on generation 31 with max fitness 0.6229510702040235
# stalled out on generation 30 with max fitness 0.21526833033632206
# stalled out on generation 48 with max fitness 1.1209076514417733
# stalled out on generation 32 with max fitness 0.7792026045860964
# Generation 49 with max fitness 0.4118978194149867
# stalled out on generation 47 with max fitness 0.3136921322335545
# Generation 49 with max fitness 0.5654615788706725
# Generation 49 with max fitness 0.28456416855040384
# stalled out on generation 31 with max fitness 0.30613117420456776
# Generation 49 with max fitness 3.1391172165812735
# stalled out on generation 31 with max fitness 0.21960296723947162
# stalled out on generation 46 with max fitness 0.5205537118141605
# stalled out on generation 45 with max fitness 0.8899757401793009
# stalled out on generation 29 with max fitness 0.37161284160650315
# stalled out on generation 33 with max fitness 0.5595284918915341
# stalled out on generation 39 with max fitness 0.257711891950216
# stalled out on generation 32 with max fitness 0.5413707251561621
# Generation 49 with max fitness 0.24614870610585338
# stalled out on generation 30 with max fitness 0.4328244791712689
# stalled out on generation 25 with max fitness 1.657616807572128
# stalled out on generation 40 with max fitness 0.4078996514584399
# stalled out on generation 34 with max fitness 0.5666307879825031
# stalled out on generation 31 with max fitness 0.40916280462313914
# stalled out on generation 28 with max fitness 0.3799547988018864
# stalled out on generation 39 with max fitness 0.36919605363138375
# Generation 49 with max fitness 0.4063491600176417
# stalled out on generation 34 with max fitness 0.6888035793967353
# stalled out on generation 43 with max fitness 0.2785668808662548
# stalled out on generation 48 with max fitness 0.48913989668248187
# Generation 49 with max fitness 0.8261766083170978
# stalled out on generation 25 with max fitness 0.8031227325909223
# stalled out on generation 29 with max fitness 0.30922031670753375
# Generation 49 with max fitness 0.5366266211836119
# stalled out on generation 47 with max fitness 0.25939431871423635
# stalled out on generation 25 with max fitness 0.32892828238595884
# stalled out on generation 43 with max fitness 0.7509888281947973
# stalled out on generation 40 with max fitness 0.6760787956706428
# stalled out on generation 49 with max fitness 0.6465828921199245
# stalled out on generation 25 with max fitness 0.39079061283310224
# Generation 49 with max fitness 0.5265186661103137
# stalled out on generation 25 with max fitness 0.24061530581766613
# stalled out on generation 36 with max fitness 0.3415614644881509
# stalled out on generation 28 with max fitness 0.555668883118191
# Generation 49 with max fitness 0.45946487799397845
# stalled out on generation 42 with max fitness 0.5238101302531945
# stalled out on generation 29 with max fitness 0.41853823844277627
# stalled out on generation 25 with max fitness 0.3189970286699578
# stalled out on generation 35 with max fitness 0.5815619748217871
# stalled out on generation 46 with max fitness 0.33743535825453663
# stalled out on generation 25 with max fitness 0.38325807505999776
# stalled out on generation 25 with max fitness 0.2057728158293877
# stalled out on generation 44 with max fitness 0.47385833787906195
# stalled out on generation 44 with max fitness 0.20908387744611281
# stalled out on generation 47 with max fitness 0.7681852476112749
# stalled out on generation 25 with max fitness 0.7295817230679933
# stalled out on generation 26 with max fitness 0.5535457133093219
# Generation 49 with max fitness 0.6763986922665276
# Generation 49 with max fitness 0.7456772178362502
# stalled out on generation 39 with max fitness 0.30788954259369455
# stalled out on generation 39 with max fitness 0.23927187125417626
# stalled out on generation 38 with max fitness 0.45465424643908836
# stalled out on generation 26 with max fitness 0.8515243736552434
# stalled out on generation 28 with max fitness 0.4413231321891576
# stalled out on generation 34 with max fitness 0.46318058623711544
# stalled out on generation 47 with max fitness 0.37419913977531577
# Generation 49 with max fitness 0.3420449475016551
# stalled out on generation 36 with max fitness 0.5247488319524726
# stalled out on generation 47 with max fitness 0.5474143174217635
# stalled out on generation 34 with max fitness 0.29349365880288913
# Generation 49 with max fitness 0.3189223396308309
# stalled out on generation 25 with max fitness 0.2056858620562088
# stalled out on generation 47 with max fitness 0.34723925231980013
# stalled out on generation 45 with max fitness 0.41959466940224915
# stalled out on generation 48 with max fitness 0.6130622210930761
# stalled out on generation 43 with max fitness 0.25363635654867206
# Generation 49 with max fitness 0.3617382453855955
# stalled out on generation 46 with max fitness 0.4560139742181868
# stalled out on generation 47 with max fitness 0.4175356357878794
# Generation 49 with max fitness 0.4757517844607696
# stalled out on generation 27 with max fitness 0.3573645452159561
# stalled out on generation 38 with max fitness 0.349643060692002
# Generation 49 with max fitness 0.5986014809561175
# stalled out on generation 27 with max fitness 0.7844398239827334
# Generation 49 with max fitness 1.6300405861354772
# Generation 49 with max fitness 0.319632328371515
# stalled out on generation 31 with max fitness 0.7344770710141466
# Generation 49 with max fitness 0.6376274263740795
# stalled out on generation 43 with max fitness 1.0069959876270402
# Generation 49 with max fitness 0.3715030317604751
# Generation 49 with max fitness 0.4447373379797335
# Generation 49 with max fitness 0.2562629374822068
# stalled out on generation 46 with max fitness 0.44346409911276424
# Generation 49 with max fitness 0.2999347223349477
# stalled out on generation 28 with max fitness 1.3518890639431835
# stalled out on generation 31 with max fitness 0.3593225496278378
# stalled out on generation 45 with max fitness 0.2911686181161842
# stalled out on generation 25 with max fitness 0.4120850332234258
# stalled out on generation 49 with max fitness 0.41956063954024686
# stalled out on generation 25 with max fitness 0.49521108529295604
# Generation 49 with max fitness 0.22222435609970612
# Generation 49 with max fitness 0.356489523545296
# Generation 49 with max fitness 0.4284511163809705
# stalled out on generation 35 with max fitness 0.60595669108486
# stalled out on generation 33 with max fitness 0.23418602664155985
# Generation 49 with max fitness 0.5475740529462046
# stalled out on generation 40 with max fitness 0.5317945807999453
# stalled out on generation 45 with max fitness 0.37823565845466545
# stalled out on generation 29 with max fitness 0.4879220681598193
# Generation 49 with max fitness 0.5087030864215877
# stalled out on generation 25 with max fitness 0.2005226332829634
# stalled out on generation 39 with max fitness 0.40717733882207297
# Generation 49 with max fitness 0.30253095335803126
# stalled out on generation 47 with max fitness 0.4319370812967206
# stalled out on generation 34 with max fitness 0.3726562110843778
# stalled out on generation 46 with max fitness 0.6001241662134117
# stalled out on generation 25 with max fitness 0.2480408589794044
# stalled out on generation 29 with max fitness 0.7567247777329822
# Generation 49 with max fitness 0.5754985382026561
# stalled out on generation 36 with max fitness 0.22625076098036062
# stalled out on generation 46 with max fitness 0.35424237385092194
# stalled out on generation 46 with max fitness 0.27930597483005937
# stalled out on generation 39 with max fitness 0.5472020704773879
# stalled out on generation 25 with max fitness 0.3492060975493865
# stalled out on generation 28 with max fitness 0.4096812049848603
# Generation 49 with max fitness 0.5767126730463276
# stalled out on generation 25 with max fitness 0.27006796515356873
# stalled out on generation 46 with max fitness 0.5559632491421351
# stalled out on generation 39 with max fitness 0.29162602213409594
# stalled out on generation 27 with max fitness 0.8546261418074445
# stalled out on generation 26 with max fitness 0.31905456099739904
# stalled out on generation 30 with max fitness 0.7632792670406612
# Generation 49 with max fitness 0.2918821135118126
# Generation 49 with max fitness 0.871180370609681
# stalled out on generation 26 with max fitness 0.31644386769079624
# Generation 49 with max fitness 0.5442420007140486
# stalled out on generation 47 with max fitness 0.751664850957303
# stalled out on generation 29 with max fitness 0.35683243950657445
# Generation 49 with max fitness 1.9934371227543084
# Generation 49 with max fitness 0.4473271492793323
# Generation 49 with max fitness 0.8176378441005521
# stalled out on generation 27 with max fitness 1.0427097692319383
# stalled out on generation 45 with max fitness 0.5602469593980504
# stalled out on generation 42 with max fitness 0.8934998717426857
# stalled out on generation 28 with max fitness 0.6448911712187976
# stalled out on generation 29 with max fitness 0.21923220745442878
# stalled out on generation 28 with max fitness 2.0941694287402868
# Generation 49 with max fitness 0.9204092390819874
# stalled out on generation 25 with max fitness 0.8988236728061022
# stalled out on generation 34 with max fitness 0.849940609222208
# stalled out on generation 25 with max fitness 0.5927445766956058
# stalled out on generation 38 with max fitness 0.28176799679934
# stalled out on generation 40 with max fitness 0.7422648608662047
# stalled out on generation 38 with max fitness 0.33409918280995843
# stalled out on generation 35 with max fitness 0.3548503064713242
# stalled out on generation 37 with max fitness 0.4890740773647046
# stalled out on generation 30 with max fitness 0.9508765982162636
# Generation 49 with max fitness 0.7373086300805343
# stalled out on generation 33 with max fitness 0.6036031770422593
# Generation 49 with max fitness 0.8835061051112088
# stalled out on generation 28 with max fitness 0.885358108350827
# Generation 49 with max fitness 0.29378910449705214
# Generation 49 with max fitness 0.41753385705152996
# stalled out on generation 40 with max fitness 0.48276511843982056
# stalled out on generation 44 with max fitness 1.2207733005650014
# stalled out on generation 36 with max fitness 0.2526350426262181
# Generation 49 with max fitness 0.4672499679288054
# stalled out on generation 38 with max fitness 0.4873178893489184
# stalled out on generation 36 with max fitness 0.20524165808555211
# stalled out on generation 30 with max fitness 0.3551668407137384
# stalled out on generation 38 with max fitness 0.3507855116589473
# stalled out on generation 30 with max fitness 0.30464752187379646
# stalled out on generation 45 with max fitness 0.5816769841967419
# stalled out on generation 25 with max fitness 0.605753496463614
# stalled out on generation 27 with max fitness 0.5002539949729765
# Generation 49 with max fitness 0.27388599284365917
# stalled out on generation 42 with max fitness 0.3784119924903078
# stalled out on generation 38 with max fitness 0.7258931303982984
# stalled out on generation 29 with max fitness 0.5978493861066774
# stalled out on generation 44 with max fitness 0.3925127589807115
# Generation 49 with max fitness 0.5530029126109369
# stalled out on generation 30 with max fitness 0.5495098420284771
# Generation 49 with max fitness 0.34253211621142476
# stalled out on generation 38 with max fitness 0.5158854093445338
# stalled out on generation 27 with max fitness 1.3922083779941654
# Generation 49 with max fitness 0.5046047075976744
# stalled out on generation 49 with max fitness 0.31452475740884317
# Generation 49 with max fitness 0.30655027494253073
# Generation 49 with max fitness 0.30287894814989413
# Generation 49 with max fitness 0.5518478342036367
# stalled out on generation 25 with max fitness 0.6462992800133704
# stalled out on generation 45 with max fitness 0.35578338341941307
# stalled out on generation 38 with max fitness 0.6493035586203869
# stalled out on generation 40 with max fitness 0.42551072275310614
# Generation 49 with max fitness 0.88147045849198
# stalled out on generation 37 with max fitness 0.41810772350568737
# stalled out on generation 26 with max fitness 0.5503733675536843
# stalled out on generation 42 with max fitness 0.7011880792991907
# Generation 49 with max fitness 0.4674412246620299
# stalled out on generation 26 with max fitness 0.3018150964561372
# stalled out on generation 35 with max fitness 0.3968886939557046
# stalled out on generation 28 with max fitness 0.25134795401112725
# stalled out on generation 26 with max fitness 0.3133329173155003
# stalled out on generation 32 with max fitness 0.27932568006946457
# stalled out on generation 37 with max fitness 0.3686026292055733
# stalled out on generation 29 with max fitness 0.37306501889147087
# stalled out on generation 33 with max fitness 0.7739408342376972
# stalled out on generation 25 with max fitness 0.5101474984398415
# stalled out on generation 25 with max fitness 0.251973558088932
# stalled out on generation 26 with max fitness 0.45391926953309164
# stalled out on generation 33 with max fitness 0.6200389931074193
# stalled out on generation 44 with max fitness 0.5663909845160047
# stalled out on generation 35 with max fitness 0.8005778230671516
# stalled out on generation 30 with max fitness 0.3193666464490376
# stalled out on generation 33 with max fitness 0.7998075461337708
# Generation 49 with max fitness 0.35864092509571305
# stalled out on generation 36 with max fitness 0.2515945846088622
# Generation 49 with max fitness 0.6578568114116794
# Generation 49 with max fitness 0.4757207465860716
# stalled out on generation 28 with max fitness 0.6523329490311601
# Generation 49 with max fitness 0.6764415057132496
# stalled out on generation 29 with max fitness 0.5425997878382007
# Generation 49 with max fitness 0.35374742260543274
# stalled out on generation 32 with max fitness 0.32746162382093075
# Generation 49 with max fitness 0.37384601413501983
# stalled out on generation 46 with max fitness 0.3820203157773704
# Generation 49 with max fitness 0.9501229730208202
# Generation 49 with max fitness 0.3082956032360549
# stalled out on generation 34 with max fitness 0.6170699430237143
# stalled out on generation 48 with max fitness 0.5897378432602794
# stalled out on generation 28 with max fitness 0.5632024284832454
# stalled out on generation 29 with max fitness 0.3817115408710591
# stalled out on generation 32 with max fitness 0.5539522014474358
# stalled out on generation 27 with max fitness 0.4759089736561584
# Generation 49 with max fitness 0.6796439917979081
# stalled out on generation 36 with max fitness 0.35255351248568556
# stalled out on generation 34 with max fitness 0.32334691813588856
# stalled out on generation 46 with max fitness 0.26321788414224645
# stalled out on generation 25 with max fitness 0.30000676159776457
# Generation 49 with max fitness 0.2415344831420856
# stalled out on generation 26 with max fitness 1.3811779538413491
# Generation 49 with max fitness 0.40003189047717336
# Generation 49 with max fitness 0.417798688816841
# Generation 49 with max fitness 0.6005110945102374
# stalled out on generation 36 with max fitness 0.6142160571681622
# Generation 49 with max fitness 0.428387160109044
# stalled out on generation 34 with max fitness 0.43243932943504937
# stalled out on generation 25 with max fitness 0.26791468574837585
# stalled out on generation 49 with max fitness 0.6837256814751302
# stalled out on generation 35 with max fitness 0.2884372103689264
# stalled out on generation 42 with max fitness 1.0189193475294522
# stalled out on generation 41 with max fitness 0.6593609096782622
# Generation 49 with max fitness 0.29959255099169574
# Generation 49 with max fitness 0.28095270027858643
# stalled out on generation 25 with max fitness 1.1067886493626504
# Generation 49 with max fitness 1.2831106690402805
# stalled out on generation 41 with max fitness 0.2955622573540458
# stalled out on generation 40 with max fitness 0.5469944878605505
# stalled out on generation 27 with max fitness 0.3637939042077797
# stalled out on generation 46 with max fitness 0.5654029197935075
# stalled out on generation 46 with max fitness 0.3703274164589168
# stalled out on generation 38 with max fitness 0.28738855241664685
# stalled out on generation 27 with max fitness 0.4049268049276358
# stalled out on generation 37 with max fitness 0.3895837609733616
# stalled out on generation 30 with max fitness 0.6687133381602071
# stalled out on generation 27 with max fitness 0.2977097258937199
# stalled out on generation 28 with max fitness 0.39166582292736674
# stalled out on generation 44 with max fitness 0.4061547047682566
# stalled out on generation 27 with max fitness 0.45784753357968117
# Generation 49 with max fitness 0.4843512729671445
# stalled out on generation 40 with max fitness 0.6626106080982394
# stalled out on generation 25 with max fitness 0.6859754223729125
# Generation 49 with max fitness 0.5415453958422882
# stalled out on generation 35 with max fitness 0.23358053283933122
# stalled out on generation 36 with max fitness 0.49388337449449726
# stalled out on generation 35 with max fitness 0.8278943660466591
# stalled out on generation 37 with max fitness 0.5997852816253538
# stalled out on generation 25 with max fitness 0.7486701303315583
# Generation 49 with max fitness 0.3068227047131284
# stalled out on generation 32 with max fitness 1.000220311474446
# Generation 49 with max fitness 1.0773003064181663
# stalled out on generation 31 with max fitness 0.6700652185068762
# stalled out on generation 35 with max fitness 0.2990266926133367
# Generation 49 with max fitness 0.42758905422932036
# stalled out on generation 43 with max fitness 0.3066923596147367
# stalled out on generation 40 with max fitness 0.6476095956924695
# stalled out on generation 33 with max fitness 0.34060741014385015
# stalled out on generation 25 with max fitness 0.39183427786647873
# stalled out on generation 25 with max fitness 0.4178215170370015
# Generation 49 with max fitness 0.5242366028047927
# stalled out on generation 29 with max fitness 1.0192334105192098
# stalled out on generation 35 with max fitness 0.5747949191334129
# stalled out on generation 27 with max fitness 0.5089374179615274
# Generation 49 with max fitness 0.47910822036703116
# stalled out on generation 25 with max fitness 0.5531010445742077
# Generation 49 with max fitness 1.0500976684505223
# stalled out on generation 29 with max fitness 0.4846851648309454
# stalled out on generation 40 with max fitness 0.32634852943934106
# stalled out on generation 45 with max fitness 0.6170899933423493
# Generation 49 with max fitness 0.5570076963179884
# Generation 49 with max fitness 0.6443516389889601
# stalled out on generation 32 with max fitness 0.6102856475301409
# stalled out on generation 41 with max fitness 0.2560647068413845
# Generation 49 with max fitness 0.6302561449122407
# stalled out on generation 36 with max fitness 0.3495212159833252
# stalled out on generation 37 with max fitness 0.5116955617243767
# Generation 49 with max fitness 0.7045189438369364
# stalled out on generation 34 with max fitness 0.22843362237180903
# Generation 49 with max fitness 0.8059075533743558
# stalled out on generation 35 with max fitness 0.45976842699866255
# stalled out on generation 30 with max fitness 0.31605963742114224
# stalled out on generation 27 with max fitness 0.8024313748868053
# stalled out on generation 25 with max fitness 0.5360913211703906
# Generation 49 with max fitness 0.7503867124858937
# Generation 49 with max fitness 0.5279693144025469
# stalled out on generation 25 with max fitness 0.3437749677568838
# stalled out on generation 30 with max fitness 0.34355907456721446
# stalled out on generation 33 with max fitness 0.2892756760944823
# stalled out on generation 37 with max fitness 0.4481077046000427
# Generation 49 with max fitness 0.6528739809810299
# stalled out on generation 31 with max fitness 0.4656603477014649
# stalled out on generation 35 with max fitness 0.49806715578359323
# stalled out on generation 29 with max fitness 0.7047242753518825
# stalled out on generation 25 with max fitness 0.2788693438042694
# Generation 49 with max fitness 0.6633400624369448
# stalled out on generation 28 with max fitness 0.3085932950666098
# Generation 49 with max fitness 0.2575258576736523
# Generation 49 with max fitness 1.158503918713596
# stalled out on generation 36 with max fitness 0.40679512444831223
# stalled out on generation 25 with max fitness 0.6416160108077384
# Generation 49 with max fitness 0.5520476156134521
# Generation 49 with max fitness 0.3214157472713969
# stalled out on generation 45 with max fitness 0.2984015158691531
# stalled out on generation 31 with max fitness 0.6300984423529428
# stalled out on generation 38 with max fitness 0.6503049904869935
# stalled out on generation 30 with max fitness 0.28201512749620616
# Generation 49 with max fitness 0.47977242281640914
# stalled out on generation 28 with max fitness 0.5111492409354009
# Generation 49 with max fitness 0.27505817874678534
# stalled out on generation 34 with max fitness 0.2552602210538143
# Generation 49 with max fitness 0.2900142498171021
# stalled out on generation 35 with max fitness 0.2624610040651108
# stalled out on generation 32 with max fitness 0.7267414374060791
# stalled out on generation 29 with max fitness 0.7143306573057443
# Generation 49 with max fitness 0.48073990919393916
# stalled out on generation 30 with max fitness 0.37917051677394864
# stalled out on generation 45 with max fitness 0.2757692500004703
# stalled out on generation 48 with max fitness 0.24754726479090866
# stalled out on generation 35 with max fitness 0.24257798093156374
# stalled out on generation 32 with max fitness 0.7096157567905239
# stalled out on generation 37 with max fitness 0.4439400093960201
# stalled out on generation 37 with max fitness 0.5238030749124086
# Generation 49 with max fitness 0.383355135656289
# stalled out on generation 49 with max fitness 0.3133038353927513
# stalled out on generation 48 with max fitness 0.3567832696336315
# stalled out on generation 49 with max fitness 0.5009366742447294
# Generation 49 with max fitness 0.6326615572305356
# stalled out on generation 32 with max fitness 0.3986528600206084
# stalled out on generation 33 with max fitness 0.4667317593147732
# Generation 49 with max fitness 1.2978501869541323
# Generation 49 with max fitness 0.6024137622609075
# stalled out on generation 43 with max fitness 0.2684232991617154
# stalled out on generation 32 with max fitness 0.5873784414702248
# stalled out on generation 37 with max fitness 0.24088265145635177
# stalled out on generation 30 with max fitness 0.4125704327048409
# stalled out on generation 28 with max fitness 0.45984831258400166
# stalled out on generation 26 with max fitness 0.3247093029824922
# stalled out on generation 30 with max fitness 0.2747412143462502
# stalled out on generation 33 with max fitness 0.8599020946872594
# stalled out on generation 36 with max fitness 0.7593593714602407
# stalled out on generation 25 with max fitness 0.563642825693529
# stalled out on generation 46 with max fitness 0.4266270304365455
# stalled out on generation 41 with max fitness 0.439434422569833
# stalled out on generation 46 with max fitness 0.270812653099717
# Generation 49 with max fitness 0.4939887906047839
# stalled out on generation 48 with max fitness 0.4326382622530754
# stalled out on generation 27 with max fitness 0.5597365816904311
# stalled out on generation 39 with max fitness 0.3482136866109641
# stalled out on generation 30 with max fitness 0.4711415537500949
# stalled out on generation 42 with max fitness 0.5823783175668188
# stalled out on generation 25 with max fitness 0.5289649158050542
# ...
# stalled out on generation 43 with max fitness 0.3197831679718315
# stalled out on generation 25 with max fitness 0.40423840674065586
# Generation 49 with max fitness 0.47519104256287814
# stalled out on generation 31 with max fitness 0.9501808639910428
# stalled out on generation 29 with max fitness 0.33749264059674744
# stalled out on generation 28 with max fitness 0.3805752371657935
# stalled out on generation 47 with max fitness 0.5691751385540247
# Generation 49 with max fitness 0.6381448884364541
# Generation 49 with max fitness 0.38379862105783025
# stalled out on generation 30 with max fitness 0.3012579112891715
# stalled out on generation 32 with max fitness 0.2733180003300179
# Generation 49 with max fitness 0.2718839647566762
# Generation 49 with max fitness 0.5350668429571347
# stalled out on generation 35 with max fitness 0.44577909212388006
# stalled out on generation 44 with max fitness 0.4089379247626052
# Generation 49 with max fitness 0.38321259827129245
# Generation 49 with max fitness 0.968061749963667
# stalled out on generation 49 with max fitness 0.26197432537318205
# Generation 49 with max fitness 0.3311536578668247
# stalled out on generation 46 with max fitness 0.4883168355779443
# Generation 49 with max fitness 0.31926851203063633
# stalled out on generation 36 with max fitness 1.1319640159754
# stalled out on generation 37 with max fitness 0.5840680274159055
# Generation 49 with max fitness 0.29642094693015275
# Generation 49 with max fitness 0.36934410839225307
# Generation 49 with max fitness 0.456395039486634
# stalled out on generation 26 with max fitness 0.8945096941077211
# stalled out on generation 49 with max fitness 0.5872530331393034
# stalled out on generation 28 with max fitness 0.1652214570143549
# Generation 49 with max fitness 0.7201253553998
# Generation 49 with max fitness 0.48158430776947536
# stalled out on generation 41 with max fitness 0.909434620062876
# stalled out on generation 30 with max fitness 0.4116976445088466
# Generation 49 with max fitness 0.2782314895423238
# Generation 49 with max fitness 0.5633678998124693
# Generation 49 with max fitness 0.45583507803289497
# stalled out on generation 46 with max fitness 0.43184158881040924
# stalled out on generation 34 with max fitness 0.3574976648394974
# Generation 49 with max fitness 0.38989959343016517
# Generation 49 with max fitness 0.3139753944728079
# Generation 49 with max fitness 0.6893938793697534
# stalled out on generation 36 with max fitness 0.6338795727739575
# stalled out on generation 25 with max fitness 0.49014553467325556
# stalled out on generation 25 with max fitness 0.6723263919196864
# stalled out on generation 47 with max fitness 0.3655769202232166
# stalled out on generation 25 with max fitness 0.24824647427691005
# Generation 49 with max fitness 0.2792942901392898
# stalled out on generation 25 with max fitness 0.612933294649911
# stalled out on generation 36 with max fitness 0.1936586626287799
# stalled out on generation 34 with max fitness 0.39913823661040887
# Generation 49 with max fitness 0.3561666349517096
# Generation 49 with max fitness 0.30118659408463627
# Generation 49 with max fitness 0.5406549986228277
# stalled out on generation 25 with max fitness 0.43698691244268206
# Generation 49 with max fitness 0.5852844667361599
# stalled out on generation 45 with max fitness 0.49453080772901814
# stalled out on generation 31 with max fitness 0.6107873957157177
# Generation 49 with max fitness 1.0698866206383815
# stalled out on generation 25 with max fitness 0.6325973148590768
# stalled out on generation 44 with max fitness 0.48471159376157485
# Generation 49 with max fitness 0.2531428195345903
# stalled out on generation 46 with max fitness 0.23602395303426668
# stalled out on generation 42 with max fitness 0.5191056668493529
# stalled out on generation 25 with max fitness 0.40145509833992854
# stalled out on generation 37 with max fitness 0.7412341230868118
# stalled out on generation 48 with max fitness 0.4547360555418629
# Generation 49 with max fitness 0.4191349450934638
# stalled out on generation 46 with max fitness 0.32528809050173374
# Generation 49 with max fitness 0.6356832881056984
# stalled out on generation 26 with max fitness 0.45654385142727655
# stalled out on generation 28 with max fitness 0.2967997988292664
# Generation 49 with max fitness 0.7376731539807106
# Generation 49 with max fitness 0.3364134120396876
# Generation 49 with max fitness 0.6082796117470947
# stalled out on generation 26 with max fitness 0.2837001972410775
# stalled out on generation 42 with max fitness 0.5619954803561669
# Generation 49 with max fitness 1.071929702298016
# stalled out on generation 40 with max fitness 0.4407945627939574
# stalled out on generation 37 with max fitness 0.4888561428519467
# Generation 49 with max fitness 0.3171926479280322
# Generation 49 with max fitness 0.3643156329296149
# stalled out on generation 31 with max fitness 0.3355109316321465
# stalled out on generation 34 with max fitness 0.5625746179812413
# stalled out on generation 39 with max fitness 0.4387434711919764
# stalled out on generation 32 with max fitness 0.5612236202868652
# stalled out on generation 26 with max fitness 0.6397091307130914
# stalled out on generation 35 with max fitness 0.30943477825946963
# Generation 49 with max fitness 0.26015491799498985
# Generation 49 with max fitness 0.40173703087553475
# stalled out on generation 28 with max fitness 0.24122421095777236
# Generation 49 with max fitness 0.4982578876706166
# Generation 49 with max fitness 1.3057957115802368
# stalled out on generation 38 with max fitness 0.4113215615838589
# stalled out on generation 33 with max fitness 0.7859990886447011
# stalled out on generation 44 with max fitness 0.42950431622041263
# stalled out on generation 40 with max fitness 0.5382570481244779
# stalled out on generation 35 with max fitness 0.6767321083517217
# stalled out on generation 31 with max fitness 0.30068786151194893
# stalled out on generation 40 with max fitness 0.3372799420095016
# stalled out on generation 25 with max fitness 0.2869478342259713
# stalled out on generation 49 with max fitness 0.5260692902094232
# Generation 49 with max fitness 0.48848270162036345
# stalled out on generation 47 with max fitness 0.7607046305055013
# stalled out on generation 44 with max fitness 0.5748609705399342
# Generation 49 with max fitness 0.2654068855218157
# stalled out on generation 26 with max fitness 0.8385992166557987
# stalled out on generation 38 with max fitness 0.8982166258628185
# stalled out on generation 38 with max fitness 0.6842379399104728
# stalled out on generation 26 with max fitness 0.436978222195729
# Generation 49 with max fitness 0.2776407246886585
# stalled out on generation 30 with max fitness 0.22514149475596423
# stalled out on generation 34 with max fitness 0.3228099732233875
# stalled out on generation 46 with max fitness 0.4044474070892918
# Generation 49 with max fitness 0.43393773690139004
# stalled out on generation 31 with max fitness 0.7562413447597169
# stalled out on generation 36 with max fitness 0.2970447149240824
# Generation 49 with max fitness 0.28973344019052105
# stalled out on generation 38 with max fitness 0.31272806015509147
# stalled out on generation 44 with max fitness 0.73926140647817
# stalled out on generation 33 with max fitness 0.20312537396017927
# stalled out on generation 40 with max fitness 0.31489649570875405
# stalled out on generation 31 with max fitness 0.5474934942473847
# stalled out on generation 32 with max fitness 0.5396266044420452
# stalled out on generation 42 with max fitness 0.28836445908733666
# stalled out on generation 25 with max fitness 0.6315562778793085
# Generation 49 with max fitness 0.2817410105131012
# Generation 49 with max fitness 0.5266375213836296
# stalled out on generation 37 with max fitness 0.8907720221018536
# stalled out on generation 26 with max fitness 0.353087586586918
# stalled out on generation 29 with max fitness 0.5224531006768753
# stalled out on generation 29 with max fitness 0.8856950844443586
# stalled out on generation 37 with max fitness 0.4197512836707325
# Generation 49 with max fitness 0.33154717183604704
# Generation 49 with max fitness 0.42332004383065985
# stalled out on generation 42 with max fitness 0.8684676007221579
# stalled out on generation 30 with max fitness 0.45740594793759654
# Generation 49 with max fitness 0.34819120124638686
# stalled out on generation 28 with max fitness 0.17542117557974457
# stalled out on generation 28 with max fitness 0.4343758716827526
# stalled out on generation 47 with max fitness 0.27859099477980487
# Generation 49 with max fitness 0.5707286308643452
# stalled out on generation 39 with max fitness 0.3792739885406287
# stalled out on generation 46 with max fitness 0.8039782630473356
# stalled out on generation 25 with max fitness 0.45753721554669974
# stalled out on generation 33 with max fitness 0.3292307825424161
# stalled out on generation 30 with max fitness 0.622827850775448
# stalled out on generation 44 with max fitness 0.5517641878699202
# stalled out on generation 36 with max fitness 0.3951669876469789
# stalled out on generation 28 with max fitness 0.2745061255782067
# stalled out on generation 46 with max fitness 0.4543225791011882
# Generation 49 with max fitness 0.272530734061084
# stalled out on generation 34 with max fitness 0.4129483880185963
# Generation 49 with max fitness 0.2725352598591296
# Generation 49 with max fitness 0.560046819692415
# stalled out on generation 25 with max fitness 0.2937043671471925
# stalled out on generation 33 with max fitness 0.8463813495595985
# stalled out on generation 26 with max fitness 0.528421858916624
# Generation 49 with max fitness 0.38659216891553244
# Generation 49 with max fitness 0.9955134141730181
# stalled out on generation 25 with max fitness 0.74514764862125
# stalled out on generation 28 with max fitness 0.5230639206347584
# Generation 49 with max fitness 0.49971991394262294
# stalled out on generation 48 with max fitness 0.304738233424954
# stalled out on generation 37 with max fitness 0.6428171556862109
# Generation 49 with max fitness 0.46030985955177095
# stalled out on generation 25 with max fitness 0.6313557374231514
# stalled out on generation 38 with max fitness 0.787148926632932
# Generation 49 with max fitness 0.45751639089265456
# stalled out on generation 25 with max fitness 0.4815536255639637
# Generation 49 with max fitness 1.0948286380641246
# stalled out on generation 42 with max fitness 0.187737506014372
# stalled out on generation 25 with max fitness 0.2353018049209982
# stalled out on generation 25 with max fitness 0.3488148491486846
# Generation 49 with max fitness 0.6235138073200077
# stalled out on generation 25 with max fitness 0.5207514395840875
# stalled out on generation 35 with max fitness 0.3519310608318169
# stalled out on generation 31 with max fitness 0.7625728342927135
# stalled out on generation 31 with max fitness 0.7658399585854553
# stalled out on generation 25 with max fitness 0.34437343121429487
# Generation 49 with max fitness 0.4610243381032624
# stalled out on generation 25 with max fitness 0.6756634030625384
# stalled out on generation 38 with max fitness 0.655084823585268
# Generation 49 with max fitness 0.2559261001830379
# Generation 49 with max fitness 0.42423770339513345
# stalled out on generation 37 with max fitness 0.5663427689177207
# Generation 49 with max fitness 0.3377023272661919
# stalled out on generation 27 with max fitness 0.6560663330026439
# stalled out on generation 25 with max fitness 0.579921428866623
# stalled out on generation 26 with max fitness 0.8461002675873012
# Generation 49 with max fitness 0.5599005535542867
# stalled out on generation 41 with max fitness 0.395031444477246
# stalled out on generation 31 with max fitness 0.8963508006707898
# Generation 49 with max fitness 0.5670022492455763
# stalled out on generation 29 with max fitness 0.7767441261175946
# stalled out on generation 44 with max fitness 0.35102753526271274
# stalled out on generation 25 with max fitness 0.419085443489532
# Generation 49 with max fitness 0.6181889009899086
# stalled out on generation 35 with max fitness 0.8900152678579081
# Generation 49 with max fitness 0.6071960740535586
# stalled out on generation 41 with max fitness 0.3188412649061375
# stalled out on generation 31 with max fitness 1.1678951435689382
# stalled out on generation 41 with max fitness 0.7001715489599771
# Generation 49 with max fitness 0.2784250833851255
# Generation 49 with max fitness 0.3888351183601562
# Generation 49 with max fitness 1.137982790675251
# stalled out on generation 31 with max fitness 0.5206364749202979
# stalled out on generation 39 with max fitness 0.4766100597025999
# stalled out on generation 36 with max fitness 0.4494399327429662
# Generation 49 with max fitness 0.5359388717208595
# stalled out on generation 43 with max fitness 0.5858572928028914
# stalled out on generation 38 with max fitness 0.29771658964735165
# stalled out on generation 25 with max fitness 1.3299891646752044
# stalled out on generation 30 with max fitness 0.7141539354011512
# stalled out on generation 37 with max fitness 0.8420977422499384
# Generation 49 with max fitness 0.2360527749874685
# stalled out on generation 33 with max fitness 0.29324044330939947
# Generation 49 with max fitness 0.41795259946997954
# stalled out on generation 30 with max fitness 0.6927292487632395
# stalled out on generation 28 with max fitness 0.286310517633767
# stalled out on generation 26 with max fitness 0.3793414311293827
# stalled out on generation 30 with max fitness 0.9295217805250244
# Generation 49 with max fitness 0.7622328536028682
# stalled out on generation 47 with max fitness 0.27229247325367595
# stalled out on generation 33 with max fitness 0.36056486175047797
# stalled out on generation 27 with max fitness 0.6926555738793216
# stalled out on generation 32 with max fitness 0.2416245849947212
# stalled out on generation 33 with max fitness 0.42131675597213325
# stalled out on generation 31 with max fitness 0.6112853895191516
# stalled out on generation 45 with max fitness 0.3893496627821837
# stalled out on generation 47 with max fitness 0.6977244449818867
# stalled out on generation 33 with max fitness 0.5699313488210103
# stalled out on generation 38 with max fitness 0.5580939228920265
# stalled out on generation 32 with max fitness 0.8099251465462577
# stalled out on generation 32 with max fitness 0.4785862780969247
# stalled out on generation 32 with max fitness 0.5560585757588696
# Generation 49 with max fitness 0.3639848295024133
# Generation 49 with max fitness 0.7244911780138791
# stalled out on generation 41 with max fitness 0.4653786152099913
# stalled out on generation 43 with max fitness 0.6601853742921239
# stalled out on generation 32 with max fitness 0.47124389664885546
# Generation 49 with max fitness 0.5964703468837224
# stalled out on generation 41 with max fitness 0.29183815496958976
# stalled out on generation 25 with max fitness 0.7663586643971726
# stalled out on generation 49 with max fitness 0.34603769008086654
# Generation 49 with max fitness 0.5162473705784688
# stalled out on generation 25 with max fitness 0.5045043075948819
# stalled out on generation 46 with max fitness 0.7100019292581964
# stalled out on generation 30 with max fitness 0.735419464226954
# stalled out on generation 26 with max fitness 0.35769864017864883
# stalled out on generation 25 with max fitness 0.5899102924483701
# stalled out on generation 25 with max fitness 0.3219536581579847
# stalled out on generation 37 with max fitness 0.4635424156737318
# Generation 49 with max fitness 1.024213529925912
# stalled out on generation 32 with max fitness 0.5784573019440594
# stalled out on generation 25 with max fitness 0.7393944714800644
# stalled out on generation 41 with max fitness 0.38579543012481377
# stalled out on generation 30 with max fitness 0.5369203564186749
# stalled out on generation 25 with max fitness 0.5070753939118471
# stalled out on generation 39 with max fitness 0.8073420145347114
# stalled out on generation 45 with max fitness 0.7652099278172351
# stalled out on generation 25 with max fitness 0.32916524212210885
# stalled out on generation 25 with max fitness 0.41020856374877923
# stalled out on generation 32 with max fitness 0.7135844062731381
# stalled out on generation 26 with max fitness 0.4556533031699796

# %%
from datetime import datetime

cdf.to_pickle("./compas_cfact_" + datetime.now().strftime("%m_%d_%Y_%H_%M") +".pkle")

# %%
from collections import namedtuple

class Model:
    
    def __init__(self, datadf, cfdf):
        self.pred = datadf['pred'].copy()
        self.label = datadf['Low'].copy()
        self.datadf = datadf.copy()
        self.cfdf = cfdf.copy()
        self.datadf['cfact_dist'] = 1/cfdf['fitness']
        self.datadf = self.datadf.query("cfact_dist == cfact_dist")
                    
    def logits(self):
        raw_logits = np.clip(np.log(self.pred / (1 - self.pred)), -100, 100)
        return raw_logits

    def num_samples(self):
        return len(self.pred)

    def base_rate(self):
        """
        Percentage of samples belonging to the positive class
        """
        return np.mean(self.label)

    def accuracy(self):
        return self.accuracies().mean()

    def precision(self):
        return (self.label[self.pred.round() == 1]).mean()

    def recall(self):
        return (self.label[self.label == 1].round()).mean()

    def tpr(self):
        """
        True positive rate
        """
        return np.mean(np.logical_and(self.pred.round() == 1, self.label == 1))

    def fpr(self):
        """
        False positive rate
        """
        return np.mean(np.logical_and(self.pred.round() == 1, self.label == 0))

    def tnr(self):
        """
        True negative rate
        """
        return np.mean(np.logical_and(self.pred.round() == 0, self.label == 0))

    def fnr(self):
        """
        False negative rate
        """
        return np.mean(np.logical_and(self.pred.round() == 0, self.label == 1))

    def fn_cost(self):
        """
        Generalized false negative cost
        """
        return 1 - self.pred[self.label == 1].mean()

    def fp_cost(self):
        """
        Generalized false positive cost
        """
        return self.pred[self.label == 0].mean()

    def accuracies(self):
        return self.pred.round() == self.label
    
    def get_burden(self):
        return self.datadf['cfact_dist'].mean()

    def burden_eq_opp(self, othr, mix_rates=None):
        has_mix_rates = not (mix_rates is None)
        if not has_mix_rates:
            mix_rates = self.eq_odds_optimal_mix_rates(othr)
        sp2p, sn2p, op2p, on2p = tuple(mix_rates)
                   
        print(sp2p, sn2p, op2p, on2p, "burden")
        # find indices close to the border and flip them
        if self.get_burden() > othr.get_burden():
            burdened_predictor = "self"
        else:
            burdened_predictor = "other"
        
        if burdened_predictor is "self":
            priv_df = self.datadf.copy()
            disa_df = othr.datadf.copy()
            priv_p2n = 1 - sp2p[0]
            dis_n2p = on2p[0]
        else:
            priv_df = othr.datadf.copy()
            disa_df = self.datadf.copy()
            priv_p2n = 1 - op2p[0]
            dis_n2p = sn2p[0]
        
        print(priv_p2n, dis_n2p)
        
        priv_pos = priv_df[priv_df['y_pred'] == 1]
        dis_neg = disa_df[disa_df['y_pred'] == 0]
        
        priv_ind = priv_pos.id.sample(frac=priv_p2n)
        disa_ind = dis_neg.id.sample(frac=dis_n2p)

        priv_df.loc[priv_ind, "pred"] = 1 - priv_df.loc[priv_ind, "pred"]
        disa_df.loc[disa_ind, "pred"] = 1 - disa_df.loc[disa_ind, "pred"]

        fair_self = None
        fair_othr = None
                
        if burdened_predictor is "self":
            fair_self = Model(priv_df, self.cfdf)
            fair_othr = Model(disa_df, othr.cfdf)
        else:
            fair_self = Model(disa_df, self.cfdf)
            fair_othr = Model(priv_df, othr.cfdf)
        
        print(fair_self.datadf)
        print(fair_othr.datadf)
        
        if not has_mix_rates:
            return fair_self, fair_othr, mix_rates
        else:
            return fair_self, fair_othr
    
    def burden_eq_odds(self, othr, mix_rates=None):
        has_mix_rates = not (mix_rates is None)
        if not has_mix_rates:
            mix_rates = self.eq_odds_optimal_mix_rates(othr)
        sp2p, sn2p, op2p, on2p = tuple(mix_rates)
                   
        print(1-sp2p, sn2p, 1-op2p, on2p, "burden")
        # find indices close to the border and flip them
        if self.get_burden() > othr.get_burden():
            burdened_predictor = "self"
        else:
            burdened_predictor = "other"
        
        if burdened_predictor is "self":
            priv_df = self.datadf
            disa_df = othr.datadf
        else:
            priv_df = othr.datadf
            disa_df = self.datadf
        
        self_df = self.datadf.copy(deep=True)
        self_df_pos = self_df[self_df["y_pred"] == 1]
        self_df_neg = self_df[self_df["y_pred"] == 0]
        othr_df = othr.datadf.copy(deep=True)
        othr_df_pos = othr_df[othr_df["y_pred"] == 1]
        othr_df_neg = othr_df[othr_df["y_pred"] == 0]
    
            
        num_sn2p = int(self_df.shape[0] *  (sn2p[0]))
        sn2p_indices = np.asarray(self_df_neg.sort_values('cfact_dist', ascending = True).id)[:num_sn2p]
        
        num_on2p = int(othr_df.shape[0] *  (on2p[0]))
        on2p_indices = np.asarray(othr_df_neg.sort_values('cfact_dist', ascending = True).id)[:num_on2p]
        
        num_sp2n = int(self_df.shape[0] *  (1 - sp2p[0]))
        sp2n_indices = np.asarray(self_df_pos.sort_values('cfact_dist', ascending = True).id)[:num_sp2n]
        
        num_op2n = int(othr_df.shape[0] *  (1 - op2p[0]))
        op2n_indices = np.asarray(othr_df_pos.sort_values('cfact_dist', ascending = True).id)[:num_op2n]

        print(num_sp2n, num_sn2p, num_op2n, num_on2p)
        
        # flip those values
        self_df.loc[sn2p_indices, 'pred'] = 1 - self_df.loc[sn2p_indices, 'pred']      
        self_df.loc[sp2n_indices, 'pred'] = 1 - self_df.loc[sp2n_indices, 'pred']      

        othr_df.loc[on2p_indices, 'pred'] = 1 - othr_df.loc[on2p_indices, 'pred']
        othr_df.loc[op2n_indices, 'pred'] = 1 - othr_df.loc[op2n_indices, 'pred']      
        
        fair_self = Model(self_df, self.cfdf)
        fair_othr = Model(othr_df, othr.cfdf)

        if not has_mix_rates:
            return fair_self, fair_othr, mix_rates
        else:
            return fair_self, fair_othr
        
    def eq_odds(self, othr, mix_rates=None):
        has_mix_rates = not (mix_rates is None)
        if not has_mix_rates:
            mix_rates = self.eq_odds_optimal_mix_rates(othr)
        sp2p, sn2p, op2p, on2p = tuple(mix_rates)

        print(sp2p, sn2p, op2p, on2p)
        
        # select random indices to flip in our model
        self_fair_pred = self.datadf.copy()
        self_pp_indices = self_fair_pred[self_fair_pred["pred"] >= .5]
        self_pn_indices = self_fair_pred[self_fair_pred["pred"] < .5]
        self_pp_indices = self_pp_indices.sample(frac=(1-sp2p[0]))
        self_pn_indices = self_pn_indices.sample(frac=sn2p[0])
        
        # flip randomly the predictions in our model
        self_fair_pred.loc[self_pn_indices.id] = 1 - self_fair_pred.loc[self_pn_indices.id]
        self_fair_pred.loc[self_pp_indices.id] = 1 - self_fair_pred.loc[self_pp_indices.id]

        # select random indices to flip in the other model
        othr_fair_pred = othr.datadf.copy()
        othr_pp_indices = othr_fair_pred[othr_fair_pred["pred"] >= .5]
        othr_pn_indices = othr_fair_pred[othr_fair_pred["pred"] < .5]
        othr_pp_indices = othr_pp_indices.sample(frac=(1-op2p[0]))
        othr_pn_indices = othr_pn_indices.sample(frac=on2p[0])

        # dlip randomly the precitions of the other model
        othr_fair_pred.loc[othr_pn_indices.id] = 1 - othr_fair_pred.loc[othr_pn_indices.id]
        othr_fair_pred.loc[othr_pp_indices.id] = 1 - othr_fair_pred.loc[othr_pp_indices.id]

        # create new model objects with the now fair predictions
        
        fair_self = Model(self_fair_pred, self.cfdf)
        fair_othr = Model(othr_fair_pred, othr.cfdf)

        if not has_mix_rates:
            return fair_self, fair_othr, mix_rates
        else:
            return fair_self, fair_othr   
        
        
    def eq_odds_optimal_mix_rates(self, othr):
        sbr = float(self.base_rate())
        obr = float(othr.base_rate())

        sp2p = cvx.Variable(1)
        sp2n = cvx.Variable(1)
        sn2p = cvx.Variable(1)
        sn2n = cvx.Variable(1)

        op2p = cvx.Variable(1)
        op2n = cvx.Variable(1)
        on2p = cvx.Variable(1)
        on2n = cvx.Variable(1)

        sfpr = self.fpr() * sp2p + self.tnr() * sn2p
        sfnr = self.fnr() * sn2n + self.tpr() * sp2n
        ofpr = othr.fpr() * op2p + othr.tnr() * on2p
        ofnr = othr.fnr() * on2n + othr.tpr() * op2n
        error = sfpr + sfnr + ofpr + ofnr

        sflip = 1 - self.pred
        sconst = self.pred
        oflip = 1 - othr.pred
        oconst = othr.pred

        sm_tn = np.logical_and(self.pred.round() == 0, self.label == 0)
        sm_fn = np.logical_and(self.pred.round() == 0, self.label == 1)
        sm_tp = np.logical_and(self.pred.round() == 1, self.label == 1)
        sm_fp = np.logical_and(self.pred.round() == 1, self.label == 0)

        om_tn = np.logical_and(othr.pred.round() == 0, othr.label == 0)
        om_fn = np.logical_and(othr.pred.round() == 0, othr.label == 1)
        om_tp = np.logical_and(othr.pred.round() == 1, othr.label == 1)
        om_fp = np.logical_and(othr.pred.round() == 1, othr.label == 0)

        spn_given_p = (sn2p * (sflip * sm_fn).mean() + sn2n * (sconst * sm_fn).mean()) / sbr + \
                      (sp2p * (sconst * sm_tp).mean() + sp2n * (sflip * sm_tp).mean()) / sbr

        spp_given_n = (sp2n * (sflip * sm_fp).mean() + sp2p * (sconst * sm_fp).mean()) / (1 - sbr) + \
                      (sn2p * (sflip * sm_tn).mean() + sn2n * (sconst * sm_tn).mean()) / (1 - sbr)

        opn_given_p = (on2p * (oflip * om_fn).mean() + on2n * (oconst * om_fn).mean()) / obr + \
                      (op2p * (oconst * om_tp).mean() + op2n * (oflip * om_tp).mean()) / obr

        opp_given_n = (op2n * (oflip * om_fp).mean() + op2p * (oconst * om_fp).mean()) / (1 - obr) + \
                      (on2p * (oflip * om_tn).mean() + on2n * (oconst * om_tn).mean()) / (1 - obr)

        constraints = [
            sp2p == 1 - sp2n,
            sn2p == 1 - sn2n,
            op2p == 1 - op2n,
            on2p == 1 - on2n,
            sp2p <= 1,
            sp2p >= 0,
            sn2p <= 1,
            sn2p >= 0,
            op2p <= 1,
            op2p >= 0,
            on2p <= 1,
            on2p >= 0,
            spp_given_n == opp_given_n,
            spn_given_p == opn_given_p,
        ]

        prob = cvx.Problem(cvx.Minimize(error), constraints)
        prob.solve()

        res = np.array([sp2p.value, sn2p.value, op2p.value, on2p.value])
        return res

    def distance(self, othr):
        x = (self.fpr() - othr.fpr()) ** 2
        y = (self.tpr() - othr.tpr()) ** 2
        return math.sqrt(x + y)
    
    def __repr__(self):
        return '\n'.join([
            'Accuracy:\t%.3f' % self.accuracy(),
            'F.P. cost:\t%.3f' % self.fp_cost(),
            'F.N. cost:\t%.3f' % self.fn_cost(),
            'Base rate:\t%.3f' % self.base_rate(),
            'Avg. score:\t%.3f' % self.pred.mean(),
        ])

# %%
cdf = pd.read_pickle("./compas_cfact.10.19.pkle")

# %%
burden_d_df = learning_data.copy()

burden_d_df.reset_index(drop=True, inplace=True)
cdf.index = burden_d_df.index
burden_d_df['id'] = burden_d_df.index
cdf['id'] = cdf.index

aa_df = burden_d_df.loc[:, X_Labels+['y_pred', 'pred', 'id']+Y_Labels][burden_d_df['race_African_American']  == 1]
c_df = burden_d_df.loc[:, X_Labels+['y_pred', 'pred', 'id']+Y_Labels][burden_d_df['race_African_American']  == 0]

aa_m = Model(aa_df, cdf.loc[aa_df.index])
c_m = Model(c_df, cdf.loc[c_df.index])

bf_aa_m, bf_c_m, _ = aa_m.burden_eq_odds(c_m)
rf_aa_m, rf_c_m, _ = aa_m.eq_odds(c_m)
p_bf_aa_m, p_bf_c_m, _ = aa_m.burden_eq_opp(c_m)

print("African American")
print("before", "\n", aa_m)
print("burden", "\n", bf_aa_m)
print("random", "\n", rf_aa_m)
print("partial", "\n", p_bf_aa_m)
print()
print("Caucasian")
print("before", "\n", c_m)
print("burden", "\n", bf_c_m)
print("random", "\n", rf_c_m)
print("partial", "\n", p_bf_c_m)
print()

# %%
b_agg_fair = pd.concat([bf_aa_m.datadf, bf_c_m.datadf])
b_agg_fair['two_year_recid'] = learning_data.loc[b_agg_fair.index, 'two_year_recid']
pb_agg_fair = pd.concat([p_bf_aa_m.datadf, p_bf_c_m.datadf])
pb_agg_fair['two_year_recid'] = learning_data.loc[pb_agg_fair.index, 'two_year_recid']
r_agg_fair = pd.concat([rf_aa_m.datadf, rf_c_m.datadf])
r_agg_fair['two_year_recid'] = learning_data.loc[r_agg_fair.index, 'two_year_recid']



print("original model's accuracy relative to ground truth")
print(learning_data[learning_data['y_pred'] == 1][learning_data['two_year_recid'] == 0].shape[0]/learning_data.shape[0])
print("burden based derived predictor's accuracy relative to ground truth")
print(b_agg_fair[b_agg_fair['pred'] >= .5][b_agg_fair['two_year_recid'] == 0].shape[0]/b_agg_fair.shape[0])
print("partial burden based derived predictor's accuracy relative to ground truth")
print(pb_agg_fair[pb_agg_fair['pred'] >= .5][pb_agg_fair['two_year_recid'] == 0].shape[0]/pb_agg_fair.shape[0])
print("random derived predictor's accuracy relative to ground truth")
print(r_agg_fair[r_agg_fair['pred'] >= .5][r_agg_fair['two_year_recid'] == 0].shape[0]/r_agg_fair.shape[0])

# %% [markdown]
# ### Demographic parity

# %%
rf_aa_dp = rf_aa_m.datadf['pred'].round().mean() 
rf_c_dp  = rf_c_m.datadf['pred'].round().mean()

bf_aa_dp = bf_aa_m.datadf['pred'].round().mean()
bf_c_dp  = bf_c_m.datadf['pred'].round().mean()

aa_dp = aa_m.datadf['pred'].round().mean()
c_dp  = c_m.datadf['pred'].round().mean()

p_bf_aa_dp = p_bf_aa_m.datadf['pred'].round().mean()
p_bf_c_dp  = p_bf_c_m.datadf['pred'].round().mean()


print("random demo parity")
print(rf_c_dp)
print(rf_aa_dp)
print()

print("burden demo parity")
print(bf_c_dp)
print(bf_aa_dp)
print()

print("partial burden demo parity")
print(p_bf_c_dp)
print(p_bf_aa_dp)
print()

print("none demo parity")
print(c_dp)
print(aa_dp)
print()

# %% [markdown]
# ### equ. odds and opp
#
# Pr{^Y= 1|A= 0,Y= 1}= Pr{^Y= 1|A= 1,Y= 1} is opp

# %%
rf_aa_eqop = rf_aa_m.datadf.query("Low == 1")['pred'].round().mean()
rf_c_eqop  = rf_c_m.datadf.query("Low == 1")['pred'].round().mean()

bf_aa_eqop = bf_aa_m.datadf.query("Low == 1")['pred'].round().mean()
bf_c_eqop  = bf_c_m.datadf.query("Low == 1")['pred'].round().mean()

p_bf_aa_eqop = p_bf_aa_m.datadf.query("Low == 1")['pred'].round().mean()
p_bf_c_eqop  = p_bf_c_m.datadf.query("Low == 1")['pred'].round().mean()

aa_eqop = aa_m.datadf.query("Low == 1")['pred'].round().mean()
c_eqop  = c_m.datadf.query("Low == 1")['pred'].round().mean()

print("random eq opp")
print(rf_c_eqop)
print(rf_aa_eqop)
print()

print("burden eq opp")
print(bf_c_eqop)
print(bf_aa_eqop)
print()

print("partial burden eq opp")
print(p_bf_c_eqop)
print(p_bf_aa_eqop)
print()

print("default eq opp")
print(c_eqop)
print(aa_eqop)
print()

# %%
rf_aa_eq1 = rf_aa_m.datadf.query("Low == 1")['pred'].round().mean()
rf_c_eq1  = rf_c_m.datadf.query("Low == 1")['pred'].round().mean()
rf_aa_eq0 = rf_aa_m.datadf.query("Low == 0")['pred'].round().mean()
rf_c_eq0  = rf_c_m.datadf.query("Low == 0")['pred'].round().mean()


bf_aa_eq1 = bf_aa_m.datadf.query("Low == 1")['pred'].round().mean()
bf_c_eq1  = bf_c_m.datadf.query("Low == 1")['pred'].round().mean()
bf_aa_eq0 = bf_aa_m.datadf.query("Low == 0")['pred'].round().mean()
bf_c_eq0  = bf_c_m.datadf.query("Low == 0")['pred'].round().mean()

p_bf_aa_eq1 = p_bf_aa_m.datadf.query("Low == 1")['pred'].round().mean()
p_bf_c_eq1  = p_bf_c_m.datadf.query("Low == 1")['pred'].round().mean()
p_bf_aa_eq0 = p_bf_aa_m.datadf.query("Low == 0")['pred'].round().mean()
p_bf_c_eq0  = p_bf_c_m.datadf.query("Low == 0")['pred'].round().mean()


aa_eq1 = aa_m.datadf.query("Low == 1")['pred'].round().mean()
c_eq1  = c_m.datadf.query("Low == 1")['pred'].round().mean()
aa_eq0 = aa_m.datadf.query("Low == 0")['pred'].round().mean()
c_eq0  = c_m.datadf.query("Low == 0")['pred'].round().mean()


print("random eq odds")
print("given y = 0")
print(rf_c_eq0)
print(rf_aa_eq0)
print("delta: ", rf_c_eq0-rf_aa_eq0)
print("given y = 1")
print(rf_c_eq1)
print(rf_aa_eq1)
print("delta: ", rf_c_eq1-rf_aa_eq1)
print()

print("burden eq odds")
print("given y = 0")
print(bf_c_eq0)
print(bf_aa_eq0)
print("delta: ", bf_c_eq0-bf_aa_eq0)
print("given y = 1")
print(bf_c_eq1)
print(bf_aa_eq1)
print("delta: ", bf_c_eq1-bf_aa_eq1)
print()

print("partial burden eq odds")
print("given y = 0")
print(p_bf_c_eq0)
print(p_bf_aa_eq0)
print("delta: ", p_bf_c_eq0-p_bf_aa_eq0)
print("given y = 1")
print(p_bf_c_eq1)
print(p_bf_aa_eq1)
print("delta: ", p_bf_c_eq1-p_bf_aa_eq1)
print()

print("default eq odds")
print("given y = 0")
print(c_eq0)
print(aa_eq0)
print("delta: ", c_eq0-aa_eq0)
print("given y = 1")
print(c_eq1)
print(aa_eq1)
print("delta: ", c_eq1-aa_eq1)
print()

# %%
rf_aa_eq1 = rf_aa_m.datadf.query("Low == 1")['pred'].round().mean()
rf_c_eq1  = rf_c_m.datadf.query("Low == 1")['pred'].round().mean()
rf_aa_eq0 = rf_aa_m.datadf.query("Low == 0")['pred'].round().mean()
rf_c_eq0  = rf_c_m.datadf.query("Low == 0")['pred'].round().mean()


bf_aa_eq1 = bf_aa_m.datadf.query("Low == 1")['pred'].round().mean()
bf_c_eq1  = bf_c_m.datadf.query("Low == 1")['pred'].round().mean()
bf_aa_eq0 = bf_aa_m.datadf.query("Low == 0")['pred'].round().mean()
bf_c_eq0  = bf_c_m.datadf.query("Low == 0")['pred'].round().mean()

p_bf_aa_eq1 = p_bf_aa_m.datadf.query("Low == 1")['pred'].round().mean()
p_bf_c_eq1  = p_bf_c_m.datadf.query("Low == 1")['pred'].round().mean()
p_bf_aa_eq0 = p_bf_aa_m.datadf.query("Low == 0")['pred'].round().mean()
p_bf_c_eq0  = p_bf_c_m.datadf.query("Low == 0")['pred'].round().mean()


aa_eq1 = aa_m.datadf.query("Low == 1")['pred'].round().mean()
c_eq1  = c_m.datadf.query("Low == 1")['pred'].round().mean()
aa_eq0 = aa_m.datadf.query("Low == 0")['pred'].round().mean()
c_eq0  = c_m.datadf.query("Low == 0")['pred'].round().mean()


print("random eq odds")
print("given y = 0")
print(rf_c_eq0)
print(rf_aa_eq0)
print("delta: ", rf_c_eq0-rf_aa_eq0)
print("given y = 1")
print(rf_c_eq1)
print(rf_aa_eq1)
print("delta: ", rf_c_eq1-rf_aa_eq1)
print()

print("burden eq odds")
print("given y = 0")
print(bf_c_eq0)
print(bf_aa_eq0)
print("delta: ", bf_c_eq0-bf_aa_eq0)
print("given y = 1")
print(bf_c_eq1)
print(bf_aa_eq1)
print("delta: ", bf_c_eq1-bf_aa_eq1)
print()

print("partial burden eq odds")
print("given y = 0")
print(p_bf_c_eq0)
print(p_bf_aa_eq0)
print("delta: ", p_bf_c_eq0-p_bf_aa_eq0)
print("given y = 1")
print(p_bf_c_eq1)
print(p_bf_aa_eq1)
print("delta: ", p_bf_c_eq1-p_bf_aa_eq1)
print()

print("default eq odds")
print("given y = 0")
print(c_eq0)
print(aa_eq0)
print("delta: ", c_eq0-aa_eq0)
print("given y = 1")
print(c_eq1)
print(aa_eq1)
print("delta: ", c_eq1-aa_eq1)
print()
